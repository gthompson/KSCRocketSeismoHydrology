# %%
# inspect daily
import os
import pandas as pd
import header
paths = header.setup_environment()
paths['daily']=os.path.join(paths['WELLDATA_TOP'], '05_DAILY_RC')
date=pd.to_datetime('2022-07-23')
df = pd.read_pickle(os.path.join(paths['daily'], f'{date.strftime("%Y%m%d")}.pkl'))
display(df.columns)
# Out:
# Linux
# Index(['1226421', '1226419', '1226420', '2149882', '2151691', '1226429',
#        'datetime', '1226419_temp', '1226421_temp', '1226420_temp',
#        '2151691_temp', '2149882_temp', '1226429_temp', '1226421_std',
#        '1226420_std', '2151691_std', '2149882_std', '1226429_std',
#        'AirPressureShallow', 'AirPressureDeep', '1226423', '2151692',
#        '1226423_temp', '2151692_temp', '2151692_std', '1226420_corrected',
#        '1226429_corrected', '1226421_corrected', '1226419_corrected',
#        '2149882_corrected', '2151691_corrected', '1226423_corrected',
#        '2151692_corrected'],
#       dtype='object')

# %%
chan = '1226421'

rawdf = pd.read_pickle(f'raw_{date.strftime("%Y-%m-%d")}_100hz.pkl')
print(rawdf.columns)
rawdf2  = rawdf.iloc[::100]
rawdf2['cal'] = (rawdf2[chan]-9787)*(-0.006724)
rawdf2.plot(x='datetime', y=chan)
rawdf2.plot(x='datetime', y='cal')
df.iloc[::100].plot(x='datetime', y=[chan])
df.iloc[::100].plot(x='datetime', y=[f'{chan}_corrected'])
df.iloc[::100].plot(x='datetime', y=['AirPressureShallow'])
# Out:
# Index(['1226421', '1226419', '1226420', '2149882', '2151691', '1226429',
#        'datetime', '1226419_temp', '1226421_temp', '1226420_temp',
#        '2151691_temp', '2149882_temp', '1226429_temp', '1226421_std',
#        '1226420_std', '2151691_std', '2149882_std', '1226429_std',
#        'DynStdDev(6)'],
#       dtype='object')
# /tmp/ipykernel_273751/1089555492.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rawdf2['cal'] = (rawdf2[chan]-9787)*(-0.006724)
# <Axes: xlabel='datetime'>
