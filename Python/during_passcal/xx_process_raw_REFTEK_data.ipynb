# %% [markdown]
# # IRIS PASSCAL - RT130 Data Processing
#
# A Jupyter notebook by Glenn Thompson based on: https://www.passcal.nmt.edu/webfm_send/3035
#
# You’ve offloaded a service run and have data from each RT130. Follow the steps in this document to convert the data to miniSEED and reorganize it into station/channel/day volumes. Then, create a stationXML for your experiment using Nexus (see step 7) before submitting data to PASSCAL. Program names are in italics. Unix commands and any command line arguments are on separate lines. Input files are denoted by < filename>. Additional documentation can be found on the PASSCAL website: https://www.passcal.nmt.edu/content/passive-source-seed-archiving-documentation

# %% [markdown]
# Import needed modules and set global variables

# %%
import os
import glob
import shutil
from pathlib import Path
import numpy as np
import pandas as pd

# %% [markdown]
# ## STEP 1. Create an organized directory structure for your data.
# Start by creating a main directory for the project *(in this Jupyter Notebook, I use the variable REFTEKDIR for this main project directory)*.
#
# Under your main project directory, make a first level directory “SVC1” for service run number 1. For each subsequent service run create a new directory, e.g. SVC2, SVC3. Create directories in the SVC1 directory for the raw data files and log files. For example:
#
#     mkdir RAW
#     mkdir LOGS
#
# Move the raw data files (either .ZIP or CF folders) into the RAW directory, e.g.
#
#     mv SVC1/ZIPFILES/*.ZIP SVC1/RAW/
#
# <b>Glenn's variations:</b> While I sometimes used *Neo* to read the Compact Flash cards, compress the data to ZIP format, and then copy the data to the laptop, I mostly just copied the data using the MacOS command line as I found it quicker, e.g.
#
#     cp -r /Volumes/UNTITLED/RT130-*/2* SVC1/RAW/
#
# At the time of writing this Jupyter Notebook, I had already completed the field project and had all the data organized into a directory structure that looks like:

# %% [raw]
# SVC1/
#     RAW/
#         2018288/
#             AB13/
#                 0/
#                 1/
#                 9/
#             9D7C/
#                 0/
#                 1/
#                 9/
#             ...
#         2018289/
#                 ...
#         ...

# %% [markdown]
# <b>Note:</b> The REFTEKDIR variable below must be set to the path of the parent directory of SVC1 (or SVC2, SVC3, etc.). If you set SERVICE_RUN = 1, the Jupyter Notebook will create the SVC1 directory underneath this (or SVC2 if you set it to 2).

# %%
#REFTEKDIR = '/raid/data/KennedySpaceCenter/duringPASSCAL/REFTEK_DATA' 
REFTEKDIR = '/home/thompsong/work/PROJECTS/KSCpasscal'
SERVICE_RUN = 2

yn = input('Is %s path to the main project directory correct? ' % REFTEKDIR)
if not (yn.lower() == 'yes' or yn.lower() == 'y'):
    REFTEKDIR = input('Enter correct path to main project directory: ')
    
yn = input('Is this service run %02d ? ' % SERVICE_RUN)
if not (yn.lower() == 'yes' or yn.lower() == 'y'):
    SERVICE_RUN = int(input('Enter correct service run number: '))
       
print('Setting paths for relative directories/files')
SVCDIR = os.path.join(REFTEKDIR, 'SVC%02d' % SERVICE_RUN)
RAWDIR = os.path.join(SVCDIR, 'RAW') 
LOGSDIR =  os.path.join(SVCDIR, 'LOGS')
CONFIGDIR = os.path.join(SVCDIR, 'CONFIG')
MSEEDDIR = os.path.join(REFTEKDIR, 'MSEED')
DAYSDIR = os.path.join(REFTEKDIR, 'DAYS')
RT2MS_OUTPUT = os.path.join(LOGSDIR, 'rt2ms.out')

print('Creating outline directory structure')
if not os.path.exists(REFTEKDIR):
    print("%s does not exist. Exiting" % REFTEKDIR)
    raise SystemExit("Killed!")  
subdirs = [SVCDIR, RAWDIR, LOGSDIR, CONFIGDIR, MSEEDDIR, DAYSDIR]
for thissubdir in subdirs:
    if not os.path.exists(thissubdir):
        print('Need to make %s' % thissubdir)
        os.mkdir(thissubdir)
        if not os.path.exists(thissubdir):
            print("%s does not exist & could not be created. Exiting" % thissubdir)
            raise SystemExit("Killed!") 
if os.path.exists(RT2MS_OUTPUT):
    os.remove(RT2MS_OUTPUT)
print('Outline directory structure created/exists')
print('Done')
# Out:
# Is /home/thompsong/work/PROJECTS/KSCpasscal path to the main project directory correct?  y
# Is this service run 02 ?  y
# Setting paths for relative directories/files
# Creating outline directory structure
# Outline directory structure created/exists
# Done

# %% [markdown]
# ### Parse RT130 9/* files to reconstruct digitizer-station history

# %%
#summary9file = '/media/sda1/summary9file.csv'
summary9file = os.path.join(SVCDIR, 'summary9file.csv')

STATIONS = ['BHP', 'TANK', 'FIRE', 'BCHH', 'DVEL', 'RBLAB']
dayfullpaths = sorted(glob.glob('%s/20?????' % RAWDIR))
if os.path.exists(summary9file):
    os.remove(summary9file)
count = 0
filehandle = open(summary9file, "w")
for thisdayfullpath in dayfullpaths:
    count = count + 1
    print('Processing %s (%d of %d)' % (thisdayfullpath, count, len(dayfullpaths) ))#, end="\r", flush=True)
    thisdaydir = os.path.basename(thisdayfullpath) # a directory like 2018365
    rt130files = sorted(glob.glob('%s/????/9/*' % thisdayfullpath))
    
    if rt130files:
        
        for rt130file in rt130files:
            #print(rt130file)
            output = os.popen('strings %s' % rt130file).read()
            if output: 
                for station in STATIONS:
                    firstindex = output.find(station)
                    if firstindex > -1:
                        break
                    
                if firstindex != -1:
                    pathparts = rt130file.split('/')
                    rt130 = pathparts[-3]
                    filehandle.write('%s, %s, %s\n' % (output[firstindex:firstindex+4], thisdaydir, rt130) )
         
        #if count>40:
        #    break
        
filehandle.close()
print('\nDone')
# Out:
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290 (1 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/003620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/013740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/023900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/034020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/044140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/054300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/064420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/074540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/084700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/094820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/104940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/115100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/125220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/135340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/145500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/155620000_0024C610
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/164140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/174300000_00075300
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/180420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/190540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/200700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/210820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/220940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8/9/231100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/002400000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/012520000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/022640000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/032800000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/042920000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/053040000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/063200000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/073320000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/083440000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/093600000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/103720000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/113840000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/124000000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/134120000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/144240000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/154400000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/164520000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9338/9/174640000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/004300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/014420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/024540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/034700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/044820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/054940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/065100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/075220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/085340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/095500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/105620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/115740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/125900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/140020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/150140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/160300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/170420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/180540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/190700000_00000000
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9406/9/190700000_00273710
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/000240000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/010400000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/020520000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/030640000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/040800000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/050920000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/061040000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/071200000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/081320000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/091440000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/101600000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/111720000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/121840000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/132000000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/142120000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/152240000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/162400000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/172520000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/182640000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/98E6/9/192800000_00000000
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/000800000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/010920000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/021040000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/031200000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/041320000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/051440000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/061600000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/071720000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/081840000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/092000000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/102120000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/112240000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/122400000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/132520000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/142640000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/152800000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/162920000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/173040000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/183200000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/193320000_00000000
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9BC5/9/193320000_001B0210
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/001930000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/012050000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/022210000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/032330000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/042450000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/052610000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/062730000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/072850000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/083010000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/093130000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/103250000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/113410000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/123530000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/133650000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/143810000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/153930000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/164050000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/9D7C/9/174210000_002BF200
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/001530000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/011650000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/021810000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/031930000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/042050000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/052210000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/062330000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/072450000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/082610000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/092730000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/102850000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/113010000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/123130000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/133250000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/143410000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/153530000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/163650000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/173810000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/183930000_00000000
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/183930000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/AB13/9/194050000_00029810
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291 (2 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/001220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/011340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/021500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/031620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/041740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/051900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/062020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/072140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/082300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/092420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/102540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/112700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/122820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/132940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/143100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/153220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/163340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/173500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/183620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/193740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/203900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/214020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/224140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8/9/234300000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292 (3 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/004420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/014540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/024700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/034820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/044940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/055100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/065220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/075340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/085500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/095620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/105740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/115900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/130020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/140140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/150300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/160420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/170540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/180700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/190820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/200940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/211100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/221220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8/9/231340000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293 (4 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/001500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/011620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/021740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/031900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/042020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/052140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/062300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/072420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/082540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/092700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/102820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/112940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/123100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/133220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/143340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/153500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/163620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/173740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/183900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/194020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/204140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/214300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/224420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8/9/234540000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294 (5 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/004700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/014820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/024940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/035100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/045220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/055340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/065500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/075620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/085740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/095900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/110020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/120140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/130300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/140420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/150540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/160700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/170820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/180940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/191100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/201220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/211340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/221500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8/9/231620000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295 (6 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/001740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/011900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/022020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/032140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/042300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/052420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/062540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/072700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/082820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/092940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/103100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/113220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/123340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/133500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/143620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/153740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/163900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/174020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/184140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/194300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/204420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/214540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/224700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8/9/234820000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296 (7 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/004940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/015100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/025220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/035340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/045500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/055620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/065740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/075900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/090020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/100140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/110300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/120420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/130540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/140700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/150820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/160940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/171100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/181220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/191340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/201500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/211620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/221740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8/9/231900000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297 (8 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/002020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/012140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/022300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/032420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/042540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/052700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/062820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/072940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/083100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/093220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/103340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/113500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/123620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/133740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/143900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/154020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/164140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/174300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/184420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/194540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/204700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/214820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/224940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8/9/235100000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298 (9 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/005220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/015340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/025500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/035620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/045740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/055900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/070020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/080140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/090300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/100420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/110540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/120700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/130820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/140940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/151100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/161220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/171340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/181500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/191620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/201740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/211900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/222020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8/9/232140000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299 (10 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/002300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/012420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/022540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/032700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/042820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/052940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/063100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/073220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/083340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/093500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/103620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/113740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/123900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/134020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/144140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/154300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/164420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/174540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/184700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/194820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/204940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/215100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/225220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8/9/235340000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300 (11 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/005500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/015620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/025740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/035900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/050020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/060140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/070300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/080420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/090540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/100700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/110820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/120940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/131100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/141220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/151340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/161500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/171620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/181740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/191900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/202020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/212140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/222300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8/9/232420000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301 (12 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/002540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/012700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/022820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/032940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/043100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/053220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/063340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/073500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/083620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/093740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/103900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/114020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/124140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/134300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/144420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/154540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/164700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/174820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/184940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/195100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/205220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/215340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/225500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8/9/235620000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302 (13 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/005740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/015900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/030020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/040140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/050300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/060420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/070540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/080700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/090820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/100940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/111100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/121220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/131340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/141500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/151620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/161740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/171900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/182020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/192140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/202300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/212420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/222540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8/9/232700000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303 (14 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/002820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/012940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/023100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/033220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/043340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/053500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/063620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/073740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/083900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/094020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/104140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/114300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/124420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/134540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/144700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/154820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/164940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/175100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/185220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/195340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/205500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/215620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/225740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8/9/235900000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304 (15 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/010020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/020140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/030300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/040420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/050540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/060700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/070820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/080940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/091100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/101220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/111340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/121500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/131620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/141740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/151900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/162020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/172140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/182300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/192420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/202540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/212700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/222820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8/9/232940000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305 (16 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/003100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/013220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/023340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/033500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/043620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/053740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/063900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/074020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/084140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/094300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/104420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/114540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/124700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/134820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/144940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/155100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/165220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/175340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/185500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/195620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/205740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/215900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8/9/230020000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306 (17 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/000140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/010300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/020420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/030540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/040700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/050820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/060940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/071100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/081220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/091340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/101500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/111620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/121740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/131900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/142020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/152140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/162300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/172420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/182540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/192700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/202820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/212940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/223100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8/9/233220000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307 (18 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/003340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/013500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/023620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/033740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/043900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/054020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/064140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/074300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/084420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/094540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/104700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/114820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/124940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/135100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/145220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/155340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/165500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/175620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/185740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/195900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/210020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/220140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8/9/230300000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018308 (19 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018308/91F8/9/000420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018308/91F8/9/010540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018308/91F8/9/020700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018308/91F8/9/030820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018308/91F8/9/040940000_00382700
# ...
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/015140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/025300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/035420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/045540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/055700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/065820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/075940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/090100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/100220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/110340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/120500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/130620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/140740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/150900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/161020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/171140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/181300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/191420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/201540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/211700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/221820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/9D7C/9/231940000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013 (89 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/004700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/014820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/024940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/035100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/045220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/055340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/065500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/075620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/085740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/095900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/110020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/120140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/130300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/140420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/150540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/160700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/170820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/180940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/191100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/201220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/211340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/221500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8/9/231620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/004040000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/014200000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/024320000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/034440000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/044600000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/054720000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/064840000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/075000000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/085120000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/095240000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/105400000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/115520000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/125640000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/135800000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/145920000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/160040000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/170200000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/180320000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/190440000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/200600000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/210720000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/220840000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/92B7/9/231000000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/002100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/012220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/022340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/032500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/042620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/052740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/062900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/073020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/083140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/093300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/103420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/113540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/123700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/133820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/143940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/154100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/164220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/174340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/184500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/194620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/204740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/214900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/225020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/9D7C/9/235140000_00382700
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014 (90 of 90)
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/001740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/011900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/022020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/032140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/042300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/052420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/062540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/072700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/082820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/092940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/103100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/113220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/123340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/133500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/143620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/153740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/163900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/174020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/184140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/194300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/204420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/214540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/224700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8/9/234820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/001120000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/011240000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/021400000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/031520000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/041640000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/051800000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/061920000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/072040000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/082200000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/092320000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/102440000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/112600000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/122720000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/132840000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/143000000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/153120000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/163240000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/173400000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/183520000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/193640000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/203800000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/213920000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/224040000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/92B7/9/234200000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/005620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/015740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/025900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/040020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/050140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/060300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/070420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/080540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/090700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/100820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/110940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/121100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/131220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/141340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/151500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/161620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/171740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/181900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/192020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/202140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/212300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/222420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9338/9/232540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/005300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/015420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/025540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/035700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/045820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/055940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/070100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/080220000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/090340000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/100500000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/110620000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/120740000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/130900000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/141020000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/151140000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/161300000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/171420000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/181540000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/191700000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/201820000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/211940000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/222100000_00382700
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/9D7C/9/232220000_00382700
#
# Done

# %%
output = os.popen('sort %s | uniq' % summary9file).read()
#print(output)
lastStationDigitizerCombo = ""
lastline = ""

for thisline in output.split('\n'):
    try:
        (station, yyyyjjj, digitizer)  = thisline.split(',')
        thisStationDigitizerCombo = '%s%s' % (station, digitizer)
        #print(lastStationDigitizerCombo, thisStationDigitizerCombo)
        if lastStationDigitizerCombo != thisStationDigitizerCombo:
            print(lastline)
            print(thisline)
        lastStationDigitizerCombo = thisStationDigitizerCombo
        lastline = thisline
    except:
        pass
print(lastline)
# Out:
# BHP1, 2018338, 92B7
# BHP1, 2019014, 92B7
# BHP2, 2018290, 91F8
# BHP2, 2019014, 91F8
# BHP3, 2018290, 9D7C
# BHP3, 2019014, 9D7C
# BHP4, 2018290, 9338
# BHP4, 2019014, 9338
# BHP5, 2018290, 9406
# BHP5, 2018338, 9406
# BHP6, 2018290, AB13
# BHP6, 2018346, AB13
# BHP7, 2018290, 98E6
# BHP7, 2018290, 98E6
# BHP8, 2018290, 9BC5
# BHP8, 2018290, 9BC5

# %% [markdown]
# ### Parse RT130 1/* files to reconstruct digitizer-GPS_Position history
# This generates a DataFrame/CSV file like:
#
# <pre>
# ,Digitizer,yyyyjjj,Latitude,LatSTD
# 0,92B7,2018222,28.0595,2.8867513458681453e-05
# 1,92B7,2018223,28.0595,1.8559214542252517e-05
# 2,92B7,2018229,28.573463888888888,2.721655270429592e-06
# 3,92B7,2018230,28.573469444444445,1.7899429988238652e-06
# 4,92B7,2018231,28.573469444444445,2.6032870393506316e-06
# 5,92B7,2018233,28.573469444444445,3.552713678800501e-15
# 6,92B7,2018234,28.573469444444445,3.552713678800501e-15
# 7,92B7,2018235,28.573469444444445,3.552713678800501e-15
# </pre>
#
# The next task will be to detect dates on which a digitizer was moved by examining plots of GPS Latitude & standard deviation.

# %%
def find_all(a_str, sub):
    start = 0
    while True:
        start = a_str.find(sub, start)
        if start == -1: return
        yield start
        start += len(sub) # use start += 1 to find overlapping matches

#list(find_all('spam spam spam spam', 'spam'))

positionDF = pd.DataFrame(columns = ['Digitizer', 'yyyyjjj', 'Latitude', 'LatSTD'])
digitizerList = list()
yyyyjjjList = list()
latitudeList = list()
latSTDList = list()
dayfullpaths = sorted(glob.glob('%s/20?????' % RAWDIR))
#summary1file = '/media/sda1/summary1file.csv'
summary1file = os.path.join(SVCDIR, 'summary1file.csv')
if os.path.exists(summary1file):
    os.remove(summary1file)
count = 0
#filehandle = open(summary1file, "w")
for thisdayfullpath in dayfullpaths:
    count = count + 1
    #print('Processing %s (%d of %d)' % (thisdayfullpath, count, len(dayfullpaths) ), end="\r", flush=True)
    thisdaydir = os.path.basename(thisdayfullpath) # a directory like 2018365
    digitizerpaths = sorted(glob.glob('%s/????' % thisdayfullpath))
    for digitizerpath in digitizerpaths:
        thisdigitizer = os.path.basename(digitizerpath)
        rt130files = sorted(glob.glob('%s/1/*' % digitizerpath))
        if rt130files:
            all_positions = list()
            for rt130file in rt130files:
                #print('Processing %s' % rt130file, end="\r", flush=True)
                
                output = os.popen('strings %s' % rt130file).read()
                if output: 
                    
                    all_indexes = list(find_all(output, 'POSITION'))
                
                    for each_index in all_indexes:
                        
                        Ndeg = output[each_index+11:each_index+13]
                        Nmin = output[each_index+14:each_index+16]
                        Nsec = output[each_index+17:each_index+22]
                        Ndecdeg = float(Ndeg) + float(Nmin)/60 + float(Nsec)/3600
                        
                        if Ndecdeg > 28.0 and Ndecdeg < 29.0:
                            #print(output[each_index+11:each_index+22], " ", Ndecdeg)
                            all_positions.append(Ndecdeg)
            if all_positions:  
                all_positions_np = np.array(all_positions)
                #print(all_positions_np)
                #print(np.median(all_positions_np))
                #print('%s, %s, %f, %f\n' % (thisdigitizer, thisdaydir, np.median(all_positions_np), np.std(all_positions_np)) )
                #filehandle.write('%s, %s, %f\n' % (thisdigitizer, thisdaydir, np.median(all_positions_np)  ) )
                digitizerList.append(thisdigitizer)
                yyyyjjjList.append(thisdaydir)
                latitudeList.append(np.median(all_positions_np))
                latSTDList.append(np.std(all_positions_np))
         
    #if count>20:
    #    break

        
#filehandle.close()
positionDF['Digitizer'] = digitizerList
positionDF['yyyyjjj'] = yyyyjjjList
positionDF['Latitude'] = latitudeList
positionDF['LatSTD'] = latSTDList

positionDF.to_csv(summary1file)

print('\nDone')
# Out:
# Done

# %% [markdown]
# #### Convert yyyyjjj strings to datetime objects

# %%
import datetime
#print(positionDF)
dates = list()
for thisyyyyjjj in positionDF['yyyyjjj']:
    thisdate = datetime.datetime.strptime(thisyyyyjjj, "%Y%j").date()
    dates.append(thisdate)
#print(dates)
positionDF['dates']=dates

# %%
import matplotlib.pyplot as plt
plt.rcParams['axes.formatter.useoffset'] = False # do not allow relative y-labels

allDigitizers = list(set(digitizerList))
for digitizer in allDigitizers:
    subsetDF = positionDF[positionDF['Digitizer']==digitizer]
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot_date(subsetDF['dates'], subsetDF['Latitude'],'*')  
    subsetDF.to_csv('latitude_' + digitizer + '.csv')
    ax.set_title(digitizer)
    if not (digitizer == 'AB13' or digitizer == '9D7C'):
        ax.set_ylim(28.572, 28.575)
    #xt = ax.get_xticks()
    #ax.set_xticks(xt[0::30])
    for xtl in ax.get_xticklabels():
        xtl.set_rotation(30)
        xtl.set_horizontalalignment('right')
    #plt.tight_layout()

# %%
import matplotlib.pyplot as plt
allDigitizers = list(set(digitizerList))
fig = plt.figure()
ax = fig.add_subplot(111)
for digitizer in allDigitizers:
    subsetDF = positionDF[positionDF['Digitizer']==digitizer]
    ax.plot_date(subsetDF['dates'], subsetDF['Latitude'],'.', label=digitizer)  
    
#xt = ax.get_xticks()
#ax.set_xticks()
ax.set_xlim(dates[0],dates[-1])
for xtl in ax.get_xticklabels():
    xtl.set_rotation(30)
    xtl.set_horizontalalignment('right')
plt.legend()
ax.set_ylim(28.51, 28.58)
plt.savefig('digitizer_lats.png')
ax.set_ylim(28.572, 28.575)
plt.savefig('digitizer_lats_zoomed.png')
#plt.tight_layout()

# %% [markdown]
# ## STEP 2. Create the parameter file(s).
# The parameter file is used by *rt2ms* to assign header information to the miniSEED files. *rt2ms* is a PASSCAL program that generates miniSEED formatted files from REFTEK RT130 raw files. In addition, *rt2ms* also modifies the headers. In the SVC1 directory, use a text editor and information from your field notes to create an ASCII parameter file (parfile) following the examples at https://www.passcal.nmt.edu/webfm_send/3035.
#
# <b>Glenn's variations</b>: PASSCAL instructions assume you construct a par file by hand for each network layout. However, I construct an Antelope-style *dbbuild_batch* pf file by hand for each network layout, and then use the PASSOFT program *batch2par* to convert this to a par file (in combination with 2 *sed* (Unix stream editor) commands to fix this. You can see *batch2par* and *sed* commands used below.
#
# <b>Update 20241110</b>
# Today I downloaded and installed the latest conda version of passoft3, and this no longer includes batch2par. Thus, I need to hand-edit the par files.
# Furthermore, rt2ms has changed. It no longer has -F, -L or -Y command line arguments. I'm trying to work out how to use it - it seems to require a different folder organization, as it doesn't like multiple digitizer folders in the same YYYYJJJ directory.
# And finally, the *.par format has changed. A blank 'location' columns is now needed, as in network.station.location.channel (SEED id). And a final 'implment_time' column is needed in UTCDateTime.isoformat() with 6-digit microseconds and perhaps a 'Z' on end.

# %%
print('For each dbbuild_batch pf file, create a corresponding par file')
pffiles = sorted(glob.glob('%s/locations*.pf' % CONFIGDIR)) # changed network to locations

for pffile in pffiles:
    parfile = pffile[:-2] + 'par' # 
    print('- %s, %s' % (pffile, parfile)) 
            
    # Create the corresponding parfile if it does not already exist
    if not os.path.exists(parfile): 
        if commandExists('batch2par'): 
            os.system("batch2par %s -m > %s" % (pffile, parfile))
            if os.path.exists(parfile): 
                # Edit the par file
                os.system("sed -i -e 's/rs200spsrs;/1;         /g' %s" % parfile)
                os.system("sed -i -e 's/x1/32/g' %s" % parfile);  
            else:
                print("- batch2par failed")
                raise SystemExit("Killed!")
        else:
            raise SystemExit("Killed!")
print('All pf files now have a corresponding par file')
print('Done')
# Out:
# For each dbbuild_batch pf file, create a corresponding par file
# - /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/CONFIG/locations20181017.pf, /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/CONFIG/locations20181017.par
# All pf files now have a corresponding par file
# Done

# %% [markdown]
# ### modify existing par file

# %%
parfiles = sorted(glob.glob('%s/locations*.par' % CONFIGDIR)) # changed network to locations

for parfile in parfiles:
    os.system(f"cat {parfile}")
    newparfile = parfile.replace('.par', '.par.reformatted')
    os.system(f'sed -e "s/[[:space:]]\+/ /g"  {parfile} > {newparfile}')
    #os.system(f"cat {newparfile}")
    print('removing comment\n')
    newparfile2 = newparfile.replace('reformatted', 'uncommented')
    os.system(f'sed -e "1s/#//" {newparfile} > {newparfile2}')
    #os.system(f"cat {newparfile2}")
    df = pd.read_csv(newparfile2, sep=';', index_col=None)
    df['location']=''
    datestr = os.path.basename(parfile).replace('locations','').replace('.par','')
    df['implement_time'] = obspy.UTCDateTime.strptime(datestr, '%Y%m%d').isoformat()+'.000000Z'
    newparfile3 = parfile.replace('.par', '.par.new')
    df = df[['das',' refchan', ' refstrm', ' netcode', ' station', 'location', ' channel', ' samplerate', ' gain', 'implement_time']]
    print(df)
    df.to_csv(newparfile3, index=False, sep=';')
    #newparfile4 = parfile.replace(".par", ".par.new")
    #os.system(f'sed -e "1s/das/#das/" {newparfile3} > {newparfile4}')
    print('final output\n')
    #os.system(f"cat {newparfile4}")
    os.system(f"sed -i 's/\;/\; /g; s/\;\s\+/\; /g' {newparfile3}")
    os.system(f"cat {newparfile3}")

print('All par files now have been converted to new format')
print('Done')
# Out:
# #das; refchan; refstrm; netcode; station; channel; samplerate; gain
# 91F8;	1;	1;         	1R;	BHP2;	EHZ;	200;	32
# 91F8;	2;	1;         	1R;	BHP2;	EH1;	200;	32
# 91F8;	3;	1;         	1R;	BHP2;	EH2;	200;	32
# 91F8;	1;	9;		1R;	BHP2;	VM1;	0.1;	32
# 91F8;	2;	9;		1R;	BHP2;	VM2;	0.1;	32
# 91F8;	3;	9;		1R;	BHP2;	VM3;	0.1;	32
# 92B7;	1;	1;         	1R;	BHP1;	EHZ;	200;	32
# 92B7;	2;	1;         	1R;	BHP1;	EH1;	200;	32
# 92B7;	3;	1;         	1R;	BHP1;	EH2;	200;	32
# 92B7;	1;	9;		1R;	BHP1;	VM1;	0.1;	32
# 92B7;	2;	9;		1R;	BHP1;	VM2;	0.1;	32
# 92B7;	3;	9;		1R;	BHP1;	VM3;	0.1;	32
# 9338;	1;	1;         	1R;	BHP4;	EHZ;	200;	32
# 9338;	2;	1;         	1R;	BHP4;	EH1;	200;	32
# 9338;	3;	1;         	1R;	BHP4;	EH2;	200;	32
# 9338;	1;	9;		1R;	BHP4;	VM1;	0.1;	32
# 9338;	2;	9;		1R;	BHP4;	VM2;	0.1;	32
# 9338;	3;	9;		1R;	BHP4;	VM3;	0.1;	32
# 9406;	1;	1;         	1R;	BHP5;	EHZ;	200;	32
# 9406;	2;	1;         	1R;	BHP5;	EH1;	200;	32
# 9406;	3;	1;         	1R;	BHP5;	EH2;	200;	32
# 9406;	1;	9;		1R;	BHP5;	VM1;	0.1;	32
# 9406;	2;	9;		1R;	BHP5;	VM2;	0.1;	32
# 9406;	3;	9;		1R;	BHP5;	VM3;	0.1;	32
# 98E6;	1;	1;         	1R;	BHP7;	EHZ;	200;	32
# 98E6;	2;	1;         	1R;	BHP7;	EH1;	200;	32
# 98E6;	3;	1;         	1R;	BHP7;	EH2;	200;	32
# 98E6;	1;	9;		1R;	BHP7;	VM1;	0.1;	32
# 98E6;	2;	9;		1R;	BHP7;	VM2;	0.1;	32
# 98E6;	3;	9;		1R;	BHP7;	VM3;	0.1;	32
# 9BC5;	1;	1;         	1R;	BHP8;	EHZ;	200;	32
# 9BC5;	2;	1;         	1R;	BHP8;	EH1;	200;	32
# 9BC5;	3;	1;         	1R;	BHP8;	EH2;	200;	32
# 9BC5;	1;	9;		1R;	BHP8;	VM1;	0.1;	32
# 9BC5;	2;	9;		1R;	BHP8;	VM2;	0.1;	32
# 9BC5;	3;	9;		1R;	BHP8;	VM3;	0.1;	32
# 9D7C;	1;	1;         	1R;	BHP3;	EHZ;	200;	32
# 9D7C;	2;	1;         	1R;	BHP3;	EH1;	200;	32
# 9D7C;	3;	1;         	1R;	BHP3;	EH2;	200;	32
# 9D7C;	1;	9;		1R;	BHP3;	VM1;	0.1;	32
# 9D7C;	2;	9;		1R;	BHP3;	VM2;	0.1;	32
# 9D7C;	3;	9;		1R;	BHP3;	VM3;	0.1;	32
# AB13;	1;	1;         	1R;	BHP6;	EHZ;	200;	32
# AB13;	2;	1;         	1R;	BHP6;	EH1;	200;	32
# AB13;	3;	1;         	1R;	BHP6;	EH2;	200;	32
# AB13;	1;	9;		1R;	BHP6;	VM1;	0.1;	32
# AB13;	2;	9;		1R;	BHP6;	VM2;	0.1;	32
# AB13;	3;	9;		1R;	BHP6;	VM3;	0.1;	32
# removing comment
#
#      das   refchan   refstrm  netcode  station location  channel   samplerate  \
# 0   91F8         1         1       1R     BHP2               EHZ        200.0
# 1   91F8         2         1       1R     BHP2               EH1        200.0
# 2   91F8         3         1       1R     BHP2               EH2        200.0
# 3   91F8         1         9       1R     BHP2               VM1          0.1
# 4   91F8         2         9       1R     BHP2               VM2          0.1
# 5   91F8         3         9       1R     BHP2               VM3          0.1
# 6   92B7         1         1       1R     BHP1               EHZ        200.0
# 7   92B7         2         1       1R     BHP1               EH1        200.0
# 8   92B7         3         1       1R     BHP1               EH2        200.0
# 9   92B7         1         9       1R     BHP1               VM1          0.1
# 10  92B7         2         9       1R     BHP1               VM2          0.1
# 11  92B7         3         9       1R     BHP1               VM3          0.1
# 12  9338         1         1       1R     BHP4               EHZ        200.0
# 13  9338         2         1       1R     BHP4               EH1        200.0
# 14  9338         3         1       1R     BHP4               EH2        200.0
# 15  9338         1         9       1R     BHP4               VM1          0.1
# 16  9338         2         9       1R     BHP4               VM2          0.1
# 17  9338         3         9       1R     BHP4               VM3          0.1
# 18  9406         1         1       1R     BHP5               EHZ        200.0
# 19  9406         2         1       1R     BHP5               EH1        200.0
# 20  9406         3         1       1R     BHP5               EH2        200.0
# 21  9406         1         9       1R     BHP5               VM1          0.1
# 22  9406         2         9       1R     BHP5               VM2          0.1
# 23  9406         3         9       1R     BHP5               VM3          0.1
# 24  98E6         1         1       1R     BHP7               EHZ        200.0
# 25  98E6         2         1       1R     BHP7               EH1        200.0
# 26  98E6         3         1       1R     BHP7               EH2        200.0
# 27  98E6         1         9       1R     BHP7               VM1          0.1
# 28  98E6         2         9       1R     BHP7               VM2          0.1
# 29  98E6         3         9       1R     BHP7               VM3          0.1
# 30  9BC5         1         1       1R     BHP8               EHZ        200.0
# 31  9BC5         2         1       1R     BHP8               EH1        200.0
# 32  9BC5         3         1       1R     BHP8               EH2        200.0
# 33  9BC5         1         9       1R     BHP8               VM1          0.1
# 34  9BC5         2         9       1R     BHP8               VM2          0.1
# 35  9BC5         3         9       1R     BHP8               VM3          0.1
# 36  9D7C         1         1       1R     BHP3               EHZ        200.0
# 37  9D7C         2         1       1R     BHP3               EH1        200.0
# 38  9D7C         3         1       1R     BHP3               EH2        200.0
# 39  9D7C         1         9       1R     BHP3               VM1          0.1
# 40  9D7C         2         9       1R     BHP3               VM2          0.1
# 41  9D7C         3         9       1R     BHP3               VM3          0.1
# 42  AB13         1         1       1R     BHP6               EHZ        200.0
# 43  AB13         2         1       1R     BHP6               EH1        200.0
# 44  AB13         3         1       1R     BHP6               EH2        200.0
# 45  AB13         1         9       1R     BHP6               VM1          0.1
# 46  AB13         2         9       1R     BHP6               VM2          0.1
# 47  AB13         3         9       1R     BHP6               VM3          0.1
#
#      gain               implement_time
# 0      32  2018-10-17T00:00:00.000000Z
# 1      32  2018-10-17T00:00:00.000000Z
# 2      32  2018-10-17T00:00:00.000000Z
# 3      32  2018-10-17T00:00:00.000000Z
# 4      32  2018-10-17T00:00:00.000000Z
# 5      32  2018-10-17T00:00:00.000000Z
# 6      32  2018-10-17T00:00:00.000000Z
# 7      32  2018-10-17T00:00:00.000000Z
# 8      32  2018-10-17T00:00:00.000000Z
# 9      32  2018-10-17T00:00:00.000000Z
# 10     32  2018-10-17T00:00:00.000000Z
# 11     32  2018-10-17T00:00:00.000000Z
# 12     32  2018-10-17T00:00:00.000000Z
# 13     32  2018-10-17T00:00:00.000000Z
# 14     32  2018-10-17T00:00:00.000000Z
# 15     32  2018-10-17T00:00:00.000000Z
# 16     32  2018-10-17T00:00:00.000000Z
# 17     32  2018-10-17T00:00:00.000000Z
# 18     32  2018-10-17T00:00:00.000000Z
# 19     32  2018-10-17T00:00:00.000000Z
# 20     32  2018-10-17T00:00:00.000000Z
# 21     32  2018-10-17T00:00:00.000000Z
# 22     32  2018-10-17T00:00:00.000000Z
# 23     32  2018-10-17T00:00:00.000000Z
# 24     32  2018-10-17T00:00:00.000000Z
# 25     32  2018-10-17T00:00:00.000000Z
# 26     32  2018-10-17T00:00:00.000000Z
# 27     32  2018-10-17T00:00:00.000000Z
# 28     32  2018-10-17T00:00:00.000000Z
# 29     32  2018-10-17T00:00:00.000000Z
# 30     32  2018-10-17T00:00:00.000000Z
# 31     32  2018-10-17T00:00:00.000000Z
# 32     32  2018-10-17T00:00:00.000000Z
# 33     32  2018-10-17T00:00:00.000000Z
# 34     32  2018-10-17T00:00:00.000000Z
# 35     32  2018-10-17T00:00:00.000000Z
# 36     32  2018-10-17T00:00:00.000000Z
# 37     32  2018-10-17T00:00:00.000000Z
# 38     32  2018-10-17T00:00:00.000000Z
# 39     32  2018-10-17T00:00:00.000000Z
# 40     32  2018-10-17T00:00:00.000000Z
# 41     32  2018-10-17T00:00:00.000000Z
# 42     32  2018-10-17T00:00:00.000000Z
# 43     32  2018-10-17T00:00:00.000000Z
# 44     32  2018-10-17T00:00:00.000000Z
# 45     32  2018-10-17T00:00:00.000000Z
# 46     32  2018-10-17T00:00:00.000000Z
# 47     32  2018-10-17T00:00:00.000000Z
# final output
#
# das; refchan; refstrm; netcode; station; location; channel; samplerate; gain; implement_time
# 91F8; 1; 1; 1R; BHP2; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 91F8; 2; 1; 1R; BHP2; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 91F8; 3; 1; 1R; BHP2; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 91F8; 1; 9; 1R; BHP2; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 91F8; 2; 9; 1R; BHP2; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 91F8; 3; 9; 1R; BHP2; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 1; 1; 1R; BHP1; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 2; 1; 1R; BHP1; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 3; 1; 1R; BHP1; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 1; 9; 1R; BHP1; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 2; 9; 1R; BHP1; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 3; 9; 1R; BHP1; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9338; 1; 1; 1R; BHP4; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9338; 2; 1; 1R; BHP4; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9338; 3; 1; 1R; BHP4; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9338; 1; 9; 1R; BHP4; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9338; 2; 9; 1R; BHP4; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9338; 3; 9; 1R; BHP4; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9406; 1; 1; 1R; BHP5; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9406; 2; 1; 1R; BHP5; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9406; 3; 1; 1R; BHP5; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9406; 1; 9; 1R; BHP5; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9406; 2; 9; 1R; BHP5; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9406; 3; 9; 1R; BHP5; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 1; 1; 1R; BHP7; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 2; 1; 1R; BHP7; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 3; 1; 1R; BHP7; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 1; 9; 1R; BHP7; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 2; 9; 1R; BHP7; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 3; 9; 1R; BHP7; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 1; 1; 1R; BHP8; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 2; 1; 1R; BHP8; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 3; 1; 1R; BHP8; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 1; 9; 1R; BHP8; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 2; 9; 1R; BHP8; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 3; 9; 1R; BHP8; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 1; 1; 1R; BHP3; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 2; 1; 1R; BHP3; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 3; 1; 1R; BHP3; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 1; 9; 1R; BHP3; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 2; 9; 1R; BHP3; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 3; 9; 1R; BHP3; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# AB13; 1; 1; 1R; BHP6; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# AB13; 2; 1; 1R; BHP6; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# AB13; 3; 1; 1R; BHP6; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# AB13; 1; 9; 1R; BHP6; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# AB13; 2; 9; 1R; BHP6; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# AB13; 3; 9; 1R; BHP6; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# All par files now have been converted to new format
# Done

# %%
dayfullpaths = sorted(glob.glob('%s/20?????' % RAWDIR))
TESTDIR = os.path.join(REFTEKDIR, 'TEST')
print(os.listdir(CONFIGDIR))
datalogger = '91F8'
for thisdayfullpath in dayfullpaths:
    print('Processing %s' % thisdayfullpath)
    thisdaydir = os.path.basename(thisdayfullpath) # a directory like 2018365
    dataloggerdir = os.path.join(thisdayfullpath, datalogger)
    outputdir = os.path.join(TESTDIR, thisdaydir, datalogger)
    print(dataloggerdir, '\t->\t',outputdir)
    if os.path.isdir(dataloggerdir):
        if not os.path.isdir(outputdir):
            os.makedirs(outputdir)
        
        os.system(f"cp -r {dataloggerdir} {outputdir}")
# Out:
# ['locations20181017.par.new', 'locations20181017.par', 'locations20181017.pf']
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018290/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018290/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018291/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018291/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018292/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018292/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018293/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018293/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018294/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018294/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018295/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018295/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018296/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018296/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018297/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018297/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018298/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018298/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018299/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018299/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018300/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018300/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018301/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018301/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018302/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018302/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018303/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018303/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018304/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018304/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018305/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018305/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018306/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018306/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018307/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018307/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018308
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018308/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018308/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018309
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018309/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018309/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018310
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018310/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018310/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018311
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018311/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018311/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018312
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018312/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018312/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018313
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018313/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018313/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018314
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018314/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018314/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018315
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018315/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018315/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018316
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018316/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018316/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018317
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018317/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018317/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018318
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018318/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018318/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018319
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018319/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018319/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018320
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018320/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018320/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018321
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018321/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018321/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018322
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018322/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018322/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018323
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018323/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018323/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018324
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018324/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018324/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018325
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018325/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018325/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018326
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018326/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018326/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018327
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018327/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018327/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018328
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018328/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018328/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018329
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018329/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018329/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018330
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018330/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018330/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018331
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018331/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018331/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018332
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018332/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018332/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018333
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018333/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018333/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018334
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018334/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018334/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018335
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018335/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018335/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018336
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018336/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018336/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018337
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018337/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018337/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018338
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018338/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018338/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018339
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018339/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018339/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018340
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018340/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018340/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018341
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018341/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018341/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018342
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018342/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018342/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018343
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018343/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018343/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018344
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018344/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018344/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018345
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018345/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018345/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018346
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018346/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018346/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018347
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018347/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018347/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018348
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018348/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018348/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018349
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018349/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018349/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018350
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018350/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018350/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018351
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018351/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018351/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018352
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018352/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018352/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018353
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018353/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018353/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018354
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018354/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018354/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018355
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018355/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018355/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018356
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018356/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018356/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018357
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018357/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018357/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018358
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018358/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018358/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018359
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018359/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018359/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018360
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018360/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018360/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018361
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018361/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018361/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018362
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018362/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018362/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018363
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018363/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018363/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018364
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018364/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018364/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018365
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2018365/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2018365/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019001
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019001/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019001/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019002
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019002/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019002/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019003
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019003/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019003/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019004
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019004/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019004/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019005
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019005/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019005/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019006
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019006/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019006/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019007
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019007/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019007/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019008
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019008/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019008/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019009
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019009/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019009/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019010
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019010/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019010/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019011
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019011/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019011/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019012/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019012/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019013/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019013/91F8
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014
# /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/RAW/2019014/91F8 	->	 /home/thompsong/work/PROJECTS/KSCpasscal/TEST/2019014/91F8

# %%
# test rt2ms
TESTDIR2 = TESTDIR + "2"
PARFILE = os.path.join(CONFIGDIR, 'locations20181017.par.new')
MSEEDIR = os.path.join(TESTDIR2, 'MSEED')
cmd = f"rt2ms -d {TESTDIR2} -p {PARFILE} -o {MSEEDDIR}"
print(cmd)
os.system(cmd)
# Out:
# rt2ms -d /home/thompsong/work/PROJECTS/KSCpasscal/TEST2 -p /home/thompsong/work/PROJECTS/KSCpasscal/SVC02/CONFIG/locations20181017.par.new -o /home/thompsong/work/PROJECTS/KSCpasscal/MSEED
# 2024-11-10 13:40:55 - INFO - rt2ms program starting
# 2024-11-10 13:40:55 - INFO - Version: 2023.4.2.0
# 2024-11-10 13:40:55 - INFO - Parsing parameter file '/home/thompsong/work/PROJECTS/KSCpasscal/SVC02/CONFIG/locations20181017.par.new'
# 2024-11-10 13:40:55 - INFO - Parameter file:
# das; refchan; refstrm; netcode; station; location; channel; samplerate; gain; implement_time
# 91F8; 1; 1; 1R; BHP2; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 91F8; 2; 1; 1R; BHP2; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 91F8; 3; 1; 1R; BHP2; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 91F8; 1; 9; 1R; BHP2; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 91F8; 2; 9; 1R; BHP2; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 91F8; 3; 9; 1R; BHP2; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 1; 1; 1R; BHP1; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 2; 1; 1R; BHP1; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 3; 1; 1R; BHP1; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 1; 9; 1R; BHP1; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 2; 9; 1R; BHP1; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 92B7; 3; 9; 1R; BHP1; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9338; 1; 1; 1R; BHP4; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9338; 2; 1; 1R; BHP4; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9338; 3; 1; 1R; BHP4; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9338; 1; 9; 1R; BHP4; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9338; 2; 9; 1R; BHP4; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9338; 3; 9; 1R; BHP4; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9406; 1; 1; 1R; BHP5; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9406; 2; 1; 1R; BHP5; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9406; 3; 1; 1R; BHP5; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9406; 1; 9; 1R; BHP5; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9406; 2; 9; 1R; BHP5; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9406; 3; 9; 1R; BHP5; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 1; 1; 1R; BHP7; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 2; 1; 1R; BHP7; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 3; 1; 1R; BHP7; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 1; 9; 1R; BHP7; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 2; 9; 1R; BHP7; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 98E6; 3; 9; 1R; BHP7; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 1; 1; 1R; BHP8; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 2; 1; 1R; BHP8; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 3; 1; 1R; BHP8; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 1; 9; 1R; BHP8; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 2; 9; 1R; BHP8; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9BC5; 3; 9; 1R; BHP8; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 1; 1; 1R; BHP3; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 2; 1; 1R; BHP3; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 3; 1; 1R; BHP3; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 1; 9; 1R; BHP3; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 2; 9; 1R; BHP3; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 9D7C; 3; 9; 1R; BHP3; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# AB13; 1; 1; 1R; BHP6; ; EHZ; 200.0; 32; 2018-10-17T00:00:00.000000Z
# AB13; 2; 1; 1R; BHP6; ; EH1; 200.0; 32; 2018-10-17T00:00:00.000000Z
# AB13; 3; 1; 1R; BHP6; ; EH2; 200.0; 32; 2018-10-17T00:00:00.000000Z
# AB13; 1; 9; 1R; BHP6; ; VM1; 0.1; 32; 2018-10-17T00:00:00.000000Z
# AB13; 2; 9; 1R; BHP6; ; VM2; 0.1; 32; 2018-10-17T00:00:00.000000Z
# AB13; 3; 9; 1R; BHP6; ; VM3; 0.1; 32; 2018-10-17T00:00:00.000000Z
# 2024-11-10 13:40:55 - INFO - Working on CF card directory: /home/thompsong/work/PROJECTS/KSCpasscal/TEST2
# 2024-11-10 13:40:55 - INFO - Parsing and writing state of health information for datalogger number: 91F8
# Traceback (most recent call last):
#   File "/home/thompsong/miniconda3/envs/passoft3/bin/rt2ms", line 8, in <module>
#     sys.exit(main())
#   File "/home/thompsong/miniconda3/envs/passoft3/lib/python3.10/site-packages/rt2ms_py3/rt2ms_py3.py", line 224, in main
#     rt130s.create_log(unit_id)
#   File "/home/thompsong/miniconda3/envs/passoft3/lib/python3.10/site-packages/rt2ms_py3/rt130_files.py", line 183, in create_log
#     rt130_soh = Rt130File.get_reftek130_from_file_soh(rt130_file.path)
#   File "/home/thompsong/miniconda3/envs/passoft3/lib/python3.10/site-packages/rt2ms_py3/rt130_files.py", line 79, in get_reftek130_from_file_soh
#     rt._data = _initial_unpack_packets_soh(string)
#   File "/home/thompsong/miniconda3/envs/passoft3/lib/python3.10/site-packages/obspy_replace/soh_packet.py", line 935, in _initial_unpack_packets_soh
#     result['time'][:] += [_get_nanoseconds_for_start_of_year(y)
#   File "/home/thompsong/miniconda3/envs/passoft3/lib/python3.10/site-packages/obspy_replace/soh_packet.py", line 935, in <listcomp>
#     result['time'][:] += [_get_nanoseconds_for_start_of_year(y)
#   File "/home/thompsong/.local/lib/python3.10/site-packages/obspy/io/reftek/util.py", line 44, in _get_nanoseconds_for_start_of_year
#     year += 2000
# OverflowError: Python integer 2000 out of bounds for uint8
# 256

# %% [markdown]
# ### helper functions for part 3
#
# *chooseCorrectParFile* selects the par file with YYYYJJJ closest to, but not exceeding, the day of Reftek data we are trying to process. For example, for 2018200 (200th day of year 2018), we match network2018200.par if it exists. Otherwise, network2018199.par is the best match, if it exists. Or whatever the closest pf is *before* the data day. But network2018201.par is not a match, since the existence of that pf would indicate the network changed on that day, so it was no longer applicable to 2018200 data.
#
# *commandExists* checks if PASSOFT/DMC commands are installed before we try to use them.

# %%
import obspy
def chooseCorrectParFile(yyyyjjj):
    correctparfile = ""
    parfilelist = sorted(glob.glob('%s/locations20*.par' % CONFIGDIR)) # network to locations
    for thisparfile in parfilelist:
        parts = thisparfile.split('locations')
        datestr = parts[1].replace('.par','')
        if len(datestr)==8:
            datestr = obspy.UTCDateTime.strptime(datestr, '%Y%m%d').strftime('%Y%J')
        if datestr < yyyyjjj:
            correctparfile = thisparfile
    return correctparfile

def commandExists(command):
    output = os.popen('which %s' % command).read()
    if output:
        return True
    else:
        print('Command %s not found.' % command)
        print('Make sure the PASSOFT tools are installed on this computer, and available on the $PATH')
        return False

# %% [markdown]
# ### STEP 3: Convert your data into miniSEED files.
# In the service run directory, convert the raw RT130 data to miniSEED. Typing *rt2ms -h* shows a list of available options.
#
# If raw data is in decompressed folders, use the following commands:
# <pre>
#     ls -d SVC1/RAW/*.cf > file.lst
#     rt2ms -F file.lst -Y -L -o MSEED/ -p <parfile> >& rt2ms.out
# </pre>
# The (-F) flag will process all files in the named list, (‐Y) puts the data in yearly directories, (-L) outputs .log and, if created, .err files, (‐o) creates an output directory, MSEED, and (‐p) points to your parfile.
#
# If raw data is in ZIP files:
# <pre>
#     rt2ms ‐D SVC1/RAW/ ‐Y ‐L -o MSEED/ ‐p <parfile> >& rt2ms.out
# </pre>
# The (‐D) flag will process all .ZIP files in a specified directory, instead of in a file list as in the previous example.
#
# When *rt2ms* finishes, move all of your log and .err files from the MSEED directory to the LOGS directory that you created in step 1.
#
# After running *rt2ms* the MSEED directory structure should look something like the example below. In the MSEED directory there will be .log files and possibly .err files along with a  subdirectory for each year that contains day directories for each stream.

# %% [raw]
# MSEED/
#     2014.019.21.29.16.98EZ.log
#     2014.019.21.29.16.98EZ.err
#     Y2014/
#         R065.01/
#         R065.02/
#         R065.03/

# %%
    # Find the corresponding parameter file for this day of the experiment
    parfile = chooseCorrectParFile(thisdaydir)
    if os.path.exists(parfile):                
        # Par file must exist if we got here. Run rt2ms.
        # Here we would ideally check that we have a full set of corresponding 0/, 1/ and 9/ files,
        # and we would also check if the hourly MSEED file already exists, and only run this if it does not
        if commandExists('rt2ms'): 
            tmplistfile = 'tmpfilelist.txt'
            rt130files = sorted(glob.glob('%s/????/[19]/*' % thisdayfullpath))
            if rt130files:
                with open(tmplistfile, 'w') as filehandle:
                    #for rt130file in rt130files:
                    #    filehandle.write('%s\n' % rt130file)
                    filehandle.writelines("%s\n" % listitem for listitem in rt130files)    
                #os.system('cat %s' % tmplistfile)
                #input('<ENTER> to continue')
                #os.system('ls %s/????/1/* > %s' % (thisdayfullpath, tmplistfile) )
                #os.system('ls %s/????/9/* >> %s' % (thisdayfullpath, tmplistfile) )


                # We can check the following RT2MS_OUTFILE if rt2ms fails
                os.system("rt2ms -F %s -Y -L -v -p %s -o %s >> %s" % (tmplistfile, parfile, MSEEDDIR, RT2MS_OUTPUT))
                os.remove(tmplistfile) # remove it here so we can never get the wrong one

                # move all *.log files to the LOGS directory
                for src_file in Path(MSEEDDIR).glob('*.log'):
                    shutil.copy(src_file, LOGSDIR)

                # move all *.err files to the LOGS directory
                for src_file in Path(MSEEDDIR).glob('*.err'):
                    shutil.copy(src_file, LOGSDIR)         
                
        else:
            raise SystemExit("Killed!")
        
    else:
        print('- no corresponding parameter file found')
        
if dayfullpaths:
    print('FINISHED CONVERTING REFTEK DATA TO MINISEED HOURLY FILES')
else:
    print('No directories like RAW/YYYYJJJ found')
print('Done')
# Out:
# ['1R.LOC00.xml', 'locations20180810.pf', 'locations20180810.par']
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018222
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018223
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018224
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018225
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018226
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018227
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018228
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018229
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018230
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018231
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018232
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018233
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018234
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018235
# FINISHED CONVERTING REFTEK DATA TO MINISEED HOURLY FILES
# Done
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v

# %%
dayfullpaths = sorted(glob.glob('%s/20?????' % RAWDIR))
print(os.listdir(CONFIGDIR))
for thisdayfullpath in dayfullpaths:
    print('Processing %s' % thisdayfullpath)
    thisdaydir = os.path.basename(thisdayfullpath) # a directory like 2018365
    
    # Find the corresponding parameter file for this day of the experiment
    parfile = chooseCorrectParFile(thisdaydir)
    if os.path.exists(parfile):                
        # Par file must exist if we got here. Run rt2ms.
        # Here we would ideally check that we have a full set of corresponding 0/, 1/ and 9/ files,
        # and we would also check if the hourly MSEED file already exists, and only run this if it does not
        if commandExists('rt2ms'): 
            tmplistfile = 'tmpfilelist.txt'
            rt130files = sorted(glob.glob('%s/????/[19]/*' % thisdayfullpath))
            if rt130files:
                with open(tmplistfile, 'w') as filehandle:
                    #for rt130file in rt130files:
                    #    filehandle.write('%s\n' % rt130file)
                    filehandle.writelines("%s\n" % listitem for listitem in rt130files)    
                #os.system('cat %s' % tmplistfile)
                #input('<ENTER> to continue')
                #os.system('ls %s/????/1/* > %s' % (thisdayfullpath, tmplistfile) )
                #os.system('ls %s/????/9/* >> %s' % (thisdayfullpath, tmplistfile) )


                # We can check the following RT2MS_OUTFILE if rt2ms fails
                os.system("rt2ms -F %s -Y -L -v -p %s -o %s >> %s" % (tmplistfile, parfile, MSEEDDIR, RT2MS_OUTPUT))
                os.remove(tmplistfile) # remove it here so we can never get the wrong one

                # move all *.log files to the LOGS directory
                for src_file in Path(MSEEDDIR).glob('*.log'):
                    shutil.copy(src_file, LOGSDIR)

                # move all *.err files to the LOGS directory
                for src_file in Path(MSEEDDIR).glob('*.err'):
                    shutil.copy(src_file, LOGSDIR)         
                
        else:
            raise SystemExit("Killed!")
        
    else:
        print('- no corresponding parameter file found')
        
if dayfullpaths:
    print('FINISHED CONVERTING REFTEK DATA TO MINISEED HOURLY FILES')
else:
    print('No directories like RAW/YYYYJJJ found')
print('Done')
# Out:
# ['1R.LOC00.xml', 'locations20180810.pf', 'locations20180810.par']
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018222
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018223
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018224
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018225
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018226
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018227
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018228
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018229
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018230
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018231
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018232
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018233
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018234
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v
# Processing /home/thompsong/work/PROJECTS/KSCpasscal/SVC00/RAW/2018235
# FINISHED CONVERTING REFTEK DATA TO MINISEED HOURLY FILES
# Done
# usage: rt2ms [-h] [-d path2rt30_cfdir] [-D path2list_cfdirs] [-p path2parfile]
#              [-o output_dir] [-e] [-X]
# rt2ms: error: unrecognized arguments: -F tmpfilelist.txt -Y -L -v

# %% [markdown]
# ## STEP 4: Reorganize the miniSEED data into station/channel/day volumes.
#
# *dataselect* is a DMC program that allows for the extracting and sorting of miniSEED data (https://github.com/iris-edu/dataselect). This will read the data from the MSEED directory and convert them into day volumes with the required naming format:
#
#     dataselect -A DAYS/%s/%s.%n.%l.%c.%Y.%j MSEED/Y*/*/*
#
# The (-A) flag writes file names in the specified custom format. The format flags are (s) for station, (n) for netcode, (l) for location, (c) for channel name, (Y) for year, and (j) for Julian date. See the help menu for more details on options (*dataselect -h*). Depending on how much data you have, you may need to run *dataselect* in a loop that runs over the different days or stations in your experiment.
#
# <b>Please note:</b> PASSCAL want data to be organized in BUD format. *dataselect -h* reveals that there is a BUD format option built in directly, so I attempt to use that here instead. This command is easier:
#
#     dataselect -BUD MSEED/Y*/*/*
#
# However, I do loop over year and day directories (as suggested) so that *dataselect* is not trying to deal with a file list that is too long for it or the operating system to handle.

# %%
if commandExists('dataselect'): 
    # SCAFFOLD. I need to install this from github. And then figure out how to
    # substitute for station, netcode, location, channel name, year and julian day
    # May need to lop over different stations (I already do by day)
    mseedyearfullpaths = sorted(glob.glob('%s/Y20??' % MSEEDDIR))
    for thismseedyearfullpath in mseedyearfullpaths:
        print('Processing %s' % thismseedyearfullpath)  
        mseeddayfullpaths = sorted(glob.glob('%s/R*.01' % thismseedyearfullpath))
        for thismseeddayfullpath in mseeddayfullpaths:
            print('dataselect: Processing %s' % thismseeddayfullpath)
            #os.system('dataselect  -A %s/%s/%s.%n.%l.%c.%Y.%j  %s/*.m' % (DAYSDIR, thismseeddayfullpath))
            os.system('dataselect -v -BUD %s %s/*.m' % (DAYSDIR, thismseeddayfullpath) )

# %% [markdown]
# ## STEP 5: Confirm your station and channel names
# In the DAYS folder just created by dataselect, check to see if you have folders for each of your stations. The data should be organized into those folders in station/channel/day volumes named STA.NET.LOC.CHAN.YEAR.JULDAY. For example: BA01.XR..HHZ.2018.039 (The .. after XR is where the location code would be if needed).
#
# If your parfile was incomplete (i.e. missing stations or channels), there will be one or more folders named with the RT130 serial numbers (e.g. 9306) instead of the desired station name (e.g. ME42). To change any miniSEED headers to correct a station name, network code, etc., see the *fixhdr* doc on the PASSCAL website (see link on the first page). After you have modified the headers with *fixhdr*, rename the files so that the station‐network‐location‐channel codes in the miniSEED file names match the corrected headers.

# %% [markdown]
# ## STEP 6. Perform quality control of waveforms and logs.
# Verify the data quality by reviewing the traces and log files (with *logpeek* and *pql*). Obvious signs of trouble include loss of GPS timing, overlaps, gaps, corrupted files, etc. Make a note of any problems. Use *fixhdr* to correct mark timing issues, and/or to convert the files to big endianess if they are not already. For more information on how to use these tools, refer to the appropriate documentation on the PASSCAL website (see link on the first page).

# %% [markdown]
# ## STEP 7. Create metadata for your experiment.
# Use *Nexus* to generate a stationXML file for your experiment metadata. See the “Metadata Generation with Nexus in a Nutshell” document on the PASSCAL website (see link on first page).

# %% [markdown]
# ## STEP 8. Send miniSEED data to PASSCAL.
# Please drop a note, with your PASSCAL project name in the subject, to <mailto>data_group@passcal.nmt.edu</mailto> before sending the data to PASSCAL so that we can set up a receiving area. Attach the stationXML created with Nexus to this email unless it is larger than 5Mb. Use our tool *data2passcal* to send the data:
#
#     data2passcal DAYS/
#
# *data2passcal* will scan all subdirectories of the DAYS folder and send any miniSEED files that have the correct file names.
