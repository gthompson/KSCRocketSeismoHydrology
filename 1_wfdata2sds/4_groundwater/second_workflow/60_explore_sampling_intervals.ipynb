# %% [markdown]
# # make plots of sampling intervals

# %%
import os
import header
paths = header.setup_environment()
import obspy
import libWellData as LLE

# timing info
start_dt = obspy.UTCDateTime(2022,7,21,0,0,0)
end_dt = obspy.UTCDateTime(2022,12,3,0,0,0)
import importlib
importlib.reload(LLE)
COMBINED_DIR = os.path.join(paths['CORRECTED'], 'combined')
LLE.plot_timediff_well_data(COMBINED_DIR, start_dt=start_dt, end_dt=end_dt)
# Out:
# Reading /home/thompsong/work/PROJECTS/KSC_EROSION/corrected/combined/timedf_masked_2022-07-21T00:00:00.000000Z_2022-12-03T00:00:00.000000Z_Sensors_1Hz.csv
# Index(['Unnamed: 0', 'datetime', 'diff'], dtype='object')
#              Unnamed: 0             datetime  diff
# 0   2022-07-22 22:26:58  2022-07-22 22:26:58   0.0
# 1   2022-07-22 22:27:09  2022-07-22 22:27:09   2.0
# 2   2022-07-26 12:02:14  2022-07-26 12:02:14   0.0
# 3   2022-07-26 12:02:25  2022-07-26 12:02:25   2.0
# 4   2022-07-26 16:03:39  2022-07-26 16:03:39   0.0
# 5   2022-07-26 16:03:50  2022-07-26 16:03:50   2.0
# 6   2022-07-29 02:06:44  2022-07-29 02:06:44   0.0
# 7   2022-07-29 02:06:55  2022-07-29 02:06:55   2.0
# 8   2022-07-30 16:16:20  2022-07-30 16:16:20   0.0
# 9   2022-07-30 16:16:31  2022-07-30 16:16:31   3.0
# 10  2022-08-01 09:03:34  2022-08-01 09:03:34   0.0
# 11  2022-08-06 00:09:55  2022-08-06 00:09:55   0.0
# 12  2022-08-06 00:10:06  2022-08-06 00:10:06   3.0
# ...
