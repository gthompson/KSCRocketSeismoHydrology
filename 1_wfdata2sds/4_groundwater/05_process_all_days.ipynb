# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import header
paths = header.setup_environment()
paths['daily']=os.path.join(paths['WELLDATA_TOP'], '05_DAILY_PSI') # raw and corrected, and done so using appropriate well barometer
if not os.path.isdir(paths['daily']):
    os.makedirs(paths['daily'])
import platform
if platform.system()=='Darwin':
    INPUTDIR = '/Users/thompsong/Dropbox/PROFESSIONAL/RESEARCH/3_Project_Documents/NASAprojects/201602_Rocket_Seismology/DATA/2022_DATA/WellData/MERGED'
else:
    INPUTDIR = os.path.join(paths['new_data'], '03_merge_inventories')
import libWellData as LLE
transducersDF = LLE.get_transducers_dataframe(paths)
#display(transducersDF)

# Load in the summary of all files - raw 4 hourly data 
dfall2 = pd.read_csv(os.path.join(INPUTDIR, 'all2.csv'))
#display(dfall2['subdir'])

LLE.qc_dataframe(dfall2)

# Split in baro, 20Hz, 100Hz
all_dataframes = LLE.split_by_subdir(dfall2, verbose=True)
#print(all_dataframes)
# Out:
# Linux
# Baro
# **********
# Displaying  Baro
#       1226421  1226419  1226420  2149882  2151691  1226429  uploaddate subdir  \
# 3         NaN      NaN      NaN      NaN      NaN      NaN    20220826   Baro
# 4         NaN      NaN      NaN      NaN      NaN      NaN    20220826   Baro
# 10        NaN      NaN      NaN      NaN      NaN      NaN    20220826   Baro
# 15        NaN      NaN      NaN      NaN      NaN      NaN    20220826   Baro
# 19        NaN      NaN      NaN      NaN      NaN      NaN    20220826   Baro
# ...       ...      ...      ...      ...      ...      ...         ...    ...
# 2258      NaN      NaN      NaN      NaN      NaN      NaN    20221202   Baro
# 2262      NaN      NaN      NaN      NaN      NaN      NaN    20221202   Baro
# 2265      NaN      NaN      NaN      NaN      NaN      NaN    20221202   Baro
# 2268      NaN      NaN      NaN      NaN      NaN      NaN    20221202   Baro
# 2270      NaN      NaN      NaN      NaN      NaN      NaN    20221202   Baro
#
#                                        basename  1226419_temp  ...  \
# 3     100hz_Baro_Sensors_20220721135421_000.csv           NaN  ...
# 4     100hz_Baro_Sensors_20220721160000_001.csv           NaN  ...
# 10    100hz_Baro_Sensors_20220721200000_002.csv           NaN  ...
# 15    100hz_Baro_Sensors_20220722000000_003.csv           NaN  ...
# 19    100hz_Baro_Sensors_20220722040000_004.csv           NaN  ...
# ...                                         ...           ...  ...
# 2258  100hz_Baro_Sensors_20221201120000_119.csv           NaN  ...
# 2262  100hz_Baro_Sensors_20221201160000_120.csv           NaN  ...
# 2265  100hz_Baro_Sensors_20221201200000_121.csv           NaN  ...
# 2268  100hz_Baro_Sensors_20221202000000_122.csv           NaN  ...
# 2270  100hz_Baro_Sensors_20221202082411_123.csv           NaN  ...
#
#       1226420_std  2151691_std  2149882_std  1226429_std  DynStdDev(6)  \
# 3             NaN          NaN          NaN          NaN           NaN
# 4             NaN          NaN          NaN          NaN           NaN
# 10            NaN          NaN          NaN          NaN           NaN
# 15            NaN          NaN          NaN          NaN           NaN
# 19            NaN          NaN          NaN          NaN           NaN
# ...           ...          ...          ...          ...           ...
# 2258          NaN          NaN          NaN          NaN           NaN
# 2262          NaN          NaN          NaN          NaN           NaN
# 2265          NaN          NaN          NaN          NaN           NaN
# 2268          NaN          NaN          NaN          NaN           NaN
# 2270          NaN          NaN          NaN          NaN           NaN
#
#       1226423  2151692  AirPressureShallow  AirPressureDeep  \
# 3         NaN      NaN           14.773304        14.766960
# 4         NaN      NaN           14.754274        14.752241
# 10        NaN      NaN           14.754250        14.748769
# 15        NaN      NaN           14.759185        14.758797
# 19        NaN      NaN           14.765824        14.759901
# ...       ...      ...                 ...              ...
# 2258      NaN      NaN           14.877370        14.876700
# 2262      NaN      NaN           14.859900        14.857960
# 2265      NaN      NaN           14.880270        14.873140
# 2268      NaN      NaN           14.886800        14.880480
# 2270      NaN      NaN           14.887970        14.885240
#
#                     datetime
# 3    2022-07-21 13:54:21.790
# 4    2022-07-21 16:00:00.010
# 10   2022-07-21 20:00:00.010
# 15   2022-07-22 00:00:00.010
# 19   2022-07-22 04:00:00.010
# ...                      ...
# 2258 2022-12-01 12:00:00.010
# 2262 2022-12-01 16:00:00.010
# 2265 2022-12-01 20:00:00.010
# 2268 2022-12-02 00:00:00.010
# 2270 2022-12-02 08:24:11.330
#
# [705 rows x 26 columns]
# 20hz
# **********
# Displaying  20hz
#       1226421  1226419  1226420  2149882  2151691  1226429  uploaddate subdir  \
# 1         NaN      NaN      NaN      NaN      NaN      NaN    20220826   20hz
# 2         NaN      NaN      NaN      NaN      NaN      NaN    20220826   20hz
# 6         NaN      NaN      NaN      NaN      NaN      NaN    20220826   20hz
# 8         NaN      NaN      NaN      NaN      NaN      NaN    20220826   20hz
# 11        NaN      NaN      NaN      NaN      NaN      NaN    20220826   20hz
# ...       ...      ...      ...      ...      ...      ...         ...    ...
# 2260      NaN      NaN      NaN      NaN      NaN      NaN    20221202   20hz
# 2263      NaN      NaN      NaN      NaN      NaN      NaN    20221202   20hz
# 2266      NaN      NaN      NaN      NaN      NaN      NaN    20221202   20hz
# 2269      NaN      NaN      NaN      NaN      NaN      NaN    20221202   20hz
# 2272      NaN      NaN      NaN      NaN      NaN      NaN    20221202   20hz
#
#                                       basename  1226419_temp  ...  \
# 1     20hz_Sensors_20Hz_20220721134750_000.csv           NaN  ...
# 2     20hz_Sensors_1Sec_20220721134750_000.csv     27.963470  ...
# 6     20hz_Sensors_20Hz_20220721160000_001.csv           NaN  ...
# 8     20hz_Sensors_1Sec_20220721160001_001.csv     27.960571  ...
# 11    20hz_Sensors_20Hz_20220721200000_002.csv           NaN  ...
# ...                                        ...           ...  ...
# 2260  20hz_Sensors_20Hz_20221201120000_119.csv           NaN  ...
# 2263  20hz_Sensors_20Hz_20221201160000_120.csv           NaN  ...
# 2266  20hz_Sensors_20Hz_20221201200000_121.csv           NaN  ...
# 2269  20hz_Sensors_20Hz_20221202000000_122.csv           NaN  ...
# 2272  20hz_Sensors_20Hz_20221202082414_123.csv           NaN  ...
#
#       1226420_std  2151691_std  2149882_std  1226429_std  DynStdDev(6)  \
# 1             NaN          NaN          NaN          NaN           NaN
# 2        0.027189          NaN          NaN          NaN           NaN
# 6             NaN          NaN          NaN          NaN           NaN
# 8        0.028026          NaN          NaN          NaN           NaN
# 11            NaN          NaN          NaN          NaN           NaN
# ...           ...          ...          ...          ...           ...
# 2260          NaN          NaN          NaN          NaN           NaN
# 2263          NaN          NaN          NaN          NaN           NaN
# 2266          NaN          NaN          NaN          NaN           NaN
# 2269          NaN          NaN          NaN          NaN           NaN
# 2272          NaN          NaN          NaN          NaN           NaN
#
#            1226423       2151692  AirPressureShallow  AirPressureDeep  \
# 1     22819.189453  15339.369141                 NaN              NaN
# 2      9078.993164   8428.339844                 NaN              NaN
# 6      9082.031250   8430.769531                 NaN              NaN
# 8      9082.081055   8430.733398                 NaN              NaN
# 11     9081.624023   8430.257812                 NaN              NaN
# ...            ...           ...                 ...              ...
# 2260   9055.340820   8414.737305                 NaN              NaN
# 2263   9060.303711   8418.320312                 NaN              NaN
# 2266   9056.477539   8415.290039                 NaN              NaN
# 2269   9055.333984   8414.057617                 NaN              NaN
# 2272   1012.704407   8409.026367                 NaN              NaN
#
#                     datetime
# 1    2022-07-21 13:47:50.000
# 2    2022-07-21 13:47:50.000
# 6    2022-07-21 16:00:00.050
# 8    2022-07-21 16:00:01.000
# 11   2022-07-21 20:00:00.050
# ...                      ...
# 2260 2022-12-01 12:00:00.050
# 2263 2022-12-01 16:00:00.050
# 2266 2022-12-01 20:00:00.050
# 2269 2022-12-02 00:00:00.050
# 2272 2022-12-02 08:24:14.000
#
# [921 rows x 26 columns]
# 100hz
# **********
# Displaying  100hz
#           1226421      1226419      1226420      2149882      2151691  \
# 0             NaN          NaN          NaN          NaN          NaN
# 5     9167.110352  9489.996094  9703.252930  8627.779297  8358.027344
# 7     9167.369141  9489.804688  9702.906250  8627.558594  8358.027344
# 9     9167.326172  9489.264648  9703.137695  8626.943359  8357.288086
# 12    9166.939453  9489.232422  9703.239258  8627.102539  8357.619141
# ...           ...          ...          ...          ...          ...
# 2259  9143.607000  9463.829000  9707.100000  8611.594000  8341.694000
# 2261  9148.351000  9468.346000  9707.489000  8614.964000  8345.216000
# 2264  9144.639000  9464.844000  9706.258000  8612.217000  8341.727000
# 2267  9143.237000  9463.555000  9705.298000  8611.196000  8340.690000
# 2271  9121.186000  2331.669000  9697.354000   514.938600  8337.354000
#
#           1226429  uploaddate subdir  \
# 0             NaN    20220826  100hz
# 5     9770.319336    20220826  100hz
# 7     9770.466797    20220826  100hz
# 9     9770.840820    20220826  100hz
# 12    9770.675781    20220826  100hz
# ...           ...         ...    ...
# 2259  9767.984000    20221202  100hz
# 2261  9769.956000    20221202  100hz
# 2264  9767.146000    20221202  100hz
# 2267  9767.320000    20221202  100hz
# 2271  9697.727000    20221202  100hz
#
#                                         basename  1226419_temp  ...  \
# 0      100hz_Sensors_1Sec_20220721133627_000.csv           NaN  ...
# 5     100hz_Sensors_100Hz_20220721160000_001.csv           NaN  ...
# 7      100hz_Sensors_1Sec_20220721160001_001.csv     27.561035  ...
# 9     100hz_Sensors_100Hz_20220721200000_002.csv           NaN  ...
# 12     100hz_Sensors_1Sec_20220721200001_002.csv     27.521179  ...
# ...                                          ...           ...  ...
# 2259  100hz_Sensors_100Hz_20221201120000_119.csv           NaN  ...
# 2261  100hz_Sensors_100Hz_20221201160000_120.csv           NaN  ...
# 2264  100hz_Sensors_100Hz_20221201200000_121.csv           NaN  ...
# 2267  100hz_Sensors_100Hz_20221202000000_122.csv           NaN  ...
# 2271  100hz_Sensors_100Hz_20221202082414_123.csv           NaN  ...
#
#       1226420_std  2151691_std  2149882_std  1226429_std  DynStdDev(6)  \
# 0             NaN          NaN          NaN          NaN           NaN
# 5             NaN          NaN          NaN          NaN           NaN
# 7        0.207875     0.274275     0.250625     0.196379      0.277220
# 9             NaN          NaN          NaN          NaN           NaN
# 12       0.188281     0.233037     0.248869     0.196529      0.283193
# ...           ...          ...          ...          ...           ...
# 2259          NaN          NaN          NaN          NaN           NaN
# 2261          NaN          NaN          NaN          NaN           NaN
# 2264          NaN          NaN          NaN          NaN           NaN
# 2267          NaN          NaN          NaN          NaN           NaN
# 2271          NaN          NaN          NaN          NaN           NaN
#
#       1226423  2151692  AirPressureShallow  AirPressureDeep  \
# 0         NaN      NaN                 NaN              NaN
# 5         NaN      NaN                 NaN              NaN
# 7         NaN      NaN                 NaN              NaN
# 9         NaN      NaN                 NaN              NaN
# 12        NaN      NaN                 NaN              NaN
# ...       ...      ...                 ...              ...
# 2259      NaN      NaN                 NaN              NaN
# 2261      NaN      NaN                 NaN              NaN
# 2264      NaN      NaN                 NaN              NaN
# 2267      NaN      NaN                 NaN              NaN
# 2271      NaN      NaN                 NaN              NaN
#
#                     datetime
# 0    2022-07-21 13:36:27.000
# 5    2022-07-21 16:00:00.010
# 7    2022-07-21 16:00:01.000
# 9    2022-07-21 20:00:00.010
# 12   2022-07-21 20:00:01.000
# ...                      ...
# 2259 2022-12-01 12:00:00.010
# 2261 2022-12-01 16:00:00.010
# 2264 2022-12-01 20:00:00.010
# 2267 2022-12-02 00:00:00.010
# 2271 2022-12-02 08:24:14.000
#
# [647 rows x 26 columns]

# %%
startt = dfall2['datetime'].min()
startt = pd.to_datetime('2022-10-02')
endt = dfall2['datetime'].max()+pd.Timedelta(hours=24)
thisdate = pd.to_datetime(f'{startt.year}-{startt.month:02d}-{startt.day:02d}')
lod = []

#csvfile = os.path.join(INPUTDIR, 'dailyshifts_nobaro.csv')
'''
if os.path.isfile(csvfile):
    dfshifts = pd.read_csv(csvfile, index_col=None)
    lod = dfshifts.to_dict('records')
    endt = pd.to_datetime(dfshifts.iloc[-1]['datetime'])+pd.Timedelta(hours=24)
    thisdate = pd.to_datetime(f'{startt.year}-{startt.month:02d}-{startt.day:02d}')
'''
print(startt, endt)
while thisdate < endt:
    print(thisdate)

    #correctedAllSensorsPSI, dcshifts, sensor_depths = LLE.process_day(dfall2, thisdate, INPUTDIR, transducersDF, apcol=None)
    correctedAllSensorsPSI = LLE.process_day(dfall2, thisdate, INPUTDIR, transducersDF, apcol='well')
    #print('dcshifts=',dcshifts)
    #print('sensor_depths=',sensor_depths)
    if isinstance(correctedAllSensorsPSI, pd.DataFrame):
        correctedAllSensorsPSI.to_pickle(os.path.join(paths['daily'], f'{thisdate.strftime("%Y%m%d")}.pkl'))
    """
    if dcshifts or not sensor_depths.empty:
        dcshifts['datetime']=thisdate.strftime("%Y-%m-%d")
        for key, value in sensor_depths.items():
            dcshifts[key] = value
        lod.append(dcshifts)

        # could just do this once at end of loop - but good to see it build each day
        dfshifts = pd.DataFrame(lod)
        dfshifts.to_csv(csvfile, index=None)
        display(dfshifts)
    """
    thisdate = thisdate + pd.Timedelta(hours=24)
# Out:
# 2022-10-02 00:00:00 2022-12-03 08:24:14
# 2022-10-02 00:00:00
# existing day pickle files found - loading these is faster
# reading raw_2022-10-02_100hz.pkl into dfdata[100hz]
# reading raw_2022-10-02_20hz.pkl into dfdata[20hz]
# reading raw_2022-10-02_baro.pkl into dfdata[baro]
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9725.412027273225, after: 0.16524712786961496
# min, max before: 9722.429, 9729.081
# min, max after: 0.14155290199999915, 0.18451151799999943
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9789.391540178256, after: 0.06819117973420172
# min, max before: 9784.729, 9793.265
# min, max after: 0.04329258000000374, 0.09816198800000411
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9120.009278369427, after: 4.484845612243982
# min, max before: 9111.697, 9127.569
# min, max after: 4.434014044000003, 4.540737371999999
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9436.559897925576, after: 3.886757697461476
# min, max before: 9427.949, 9453.962
# min, max after: 3.7746707580000027, 3.9422204909999965
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8588.907470385058, after: 9.246622176640718
# min, max before: 8581.873, 8599.233
# min, max after: 9.163243524999999, 9.303425525000003
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8320.979268261697, after: 8.899374797813284
# min, max before: 8314.295, 8326.301
# min, max after: 8.856045258000004, 8.95379811
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9027.603877532281, after: 3.6647331893025488
# min, max before: 8997.94140625, 9034.904296875
# min, max after: 3.6183974277343753, 3.85300089453125
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8393.201482147468, after: 8.566888486498629
# min, max before: 8387.1162109375, 8398.33984375
# min, max after: 8.5255863359375, 8.615801896484376
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-10-03 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221003000000_294.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221003000000_429.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221003000000_051.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221003040000_295.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221003040000_430.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221003040000_052.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221003080000_296.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221003080000_431.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221003080000_053.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221003120000_432.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221003120000_297.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221003120000_054.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221003160000_433.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221003160000_298.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221003160000_055.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221003200000_299.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221003200000_434.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221003200000_056.csv
# - loading
# saving to raw_2022-10-03_100hz.pkl
# saving to raw_2022-10-03_baro.pkl
# saving to raw_2022-10-03_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9724.206080612152, after: 0.17303513140671722
# min, max before: 9722.054, 9726.206
# min, max after: 0.16011965199999917, 0.18693326799999943
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9786.689319805437, after: 0.08556105229063253
# min, max before: 9782.414, 9791.164
# min, max after: 0.056797807999995696, 0.11304280799999569
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9133.379108516096, after: 4.394946874337824
# min, max before: 9122.4, 9144.636
# min, max after: 4.319255535999997, 4.468770400000002
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9450.544207470719, after: 3.7966847596811095
# min, max before: 9439.073, 9462.314
# min, max after: 3.7208755259999977, 3.870570806999998
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8600.137291419338, after: 9.15594137178892
# min, max before: 8590.514, 8610.182
# min, max after: 9.074830349999996, 9.233649450000007
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8332.128254721416, after: 8.808599750058269
# min, max before: 8322.689, 8341.928
# min, max after: 8.728810224, 8.885454161999997
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9041.894154417198, after: 3.5740328019141114
# min, max before: 9030.93359375, 9053.4169921875
# min, max after: 3.5008973505859378, 3.64359948046875
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8404.517851062696, after: 8.47592751315799
# min, max before: 8395.7001953125, 8414.1474609375
# min, max after: 8.398524708984375, 8.546803830078124
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-10-04 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221004000000_435.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221004000000_300.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221004000000_057.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221004040000_436.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221004040000_301.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221004040000_058.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221004080000_437.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221004080000_302.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221004080000_059.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221004120000_303.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221004120000_438.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221004120000_060.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221004160000_304.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221004160000_439.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221004160000_061.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221004200000_305.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221004200000_440.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221004200000_062.csv
# - loading
# saving to raw_2022-10-04_baro.pkl
# saving to raw_2022-10-04_100hz.pkl
# saving to raw_2022-10-04_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9725.412152710282, after: 0.16524631779699023
# min, max before: 9721.938, 9728.054
# min, max after: 0.14818526799999945, 0.18768239599999934
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9785.290990735191, after: 0.09454951155413364
# min, max before: 9780.371, 9790.95
# min, max after: 0.05817339999999532, 0.12617521200000523
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9147.44004079076, after: 4.30040116572287
# min, max before: 9135.863, 9158.339
# min, max after: 4.227116564, 4.378245188000004
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9465.222096905401, after: 3.70214447383238
# min, max before: 9451.57, 9476.498
# min, max after: 3.6295163820000025, 3.7900776300000016
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8612.087740093002, after: 9.059441498749045
# min, max before: 8601.094000000001, 8621.683
# min, max after: 8.981959774999993, 9.148215949999994
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8343.995627667573, after: 8.711975599530666
# min, max before: 8333.284, 8353.259
# min, max after: 8.636553222, 8.799189672000002
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9056.853084198516, after: 3.4790884745920585
# min, max before: 9045.1787109375, 9067.69921875
# min, max after: 3.41024805859375, 3.5531857216796876
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8416.594832064893, after: 8.378852739862406
# min, max before: 8406.32421875, 8425.7197265625
# min, max after: 8.305506837890626, 8.4614079296875
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-10-05 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221005000000_306.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221005000000_441.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221005000000_063.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221005040000_307.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221005040000_442.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221005040000_064.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221005080000_308.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221005080000_443.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221005080000_065.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221005120000_309.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221005120000_444.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221005120000_066.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221005160000_445.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221005160000_310.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221005160000_067.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221005200000_311.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221005200000_446.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221005200000_068.csv
# - loading
# saving to raw_2022-10-05_100hz.pkl
# saving to raw_2022-10-05_baro.pkl
# saving to raw_2022-10-05_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9738.295983414388, after: 0.08204253910986717
# min, max before: 9724.869, 9753.959
# min, max after: -0.019109222000004793, 0.16875399799999616
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9782.254741919485, after: 0.11406651894162372
# min, max before: 9777.405, 9787.102
# min, max after: 0.08290834399999504, 0.14524065999999577
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9139.915003318536, after: 4.350999517686019
# min, max before: 9122.017, 9156.136
# min, max after: 4.241929535999997, 4.471345692000001
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9457.428948907906, after: 3.752340140084064
# min, max before: 9438.983, 9474.518
# min, max after: 3.6422695619999996, 3.8711504969999986
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8604.723033584318, after: 9.118911503806626
# min, max before: 8587.168, 8619.497
# min, max after: 8.999611725000005, 9.260668400000004
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8336.64905474364, after: 8.771791396277333
# min, max before: 8319.427, 8351.103
# min, max after: 8.654107374000008, 8.912013366000002
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9048.937492078405, after: 3.529328737778387
# min, max before: 9005.2216796875, 9065.7958984375
# min, max after: 3.4223284326171877, 3.8067929990234375
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8409.215214281909, after: 8.438170107602065
# min, max before: 8392.1904296875, 8423.5654296875
# min, max after: 8.322823076171876, 8.575015326171876
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-10-06 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221006000000_447.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221006000000_312.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221006000000_069.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221006040000_448.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221006040000_313.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221006040000_070.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221006080000_314.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221006080000_449.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221006080000_071.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221006120000_315.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221006120000_450.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221006120000_072.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221006160000_451.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221006160000_316.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221006160000_073.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221006200000_452.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221006200000_317.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221006200000_074.csv
# - loading
# saving to raw_2022-10-06_baro.pkl
# saving to raw_2022-10-06_100hz.pkl
# saving to raw_2022-10-06_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9738.118744867354, after: 0.08318714564658186
# min, max before: 9721.359, 9765.641
# min, max after: -0.09455157799999755, 0.19142157799999757
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9779.368157457186, after: 0.1326214838652731
# min, max before: 9773.995, 9784.106
# min, max after: 0.10216663200000149, 0.16716013999999485
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9141.536630788876, after: 4.340095694575517
# min, max before: 9128.302, 9152.733
# min, max after: 4.264811307999999, 4.429085352000002
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9459.206505831831, after: 3.7408908959371936
# min, max before: 9445.359, 9471.057
# min, max after: 3.6645618629999954, 3.8300826809999973
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8605.761919665847, after: 9.110522498698215
# min, max before: 8593.874, 8615.908
# min, max after: 9.028592900000005, 9.206517450000002
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8337.638379143398, after: 8.763736317014411
# min, max before: 8325.902, 8347.882
# min, max after: 8.680332756000004, 8.859293916
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9050.778747748343, after: 3.5176422880412828
# min, max before: 9010.53515625, 9062.1728515625
# min, max after: 3.4453239111328124, 3.7730683632812503
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8410.284279664038, after: 8.429576960060468
# min, max before: 8399.2080078125, 8420.2900390625
# min, max after: 8.349150666015625, 8.518608033203124
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-10-07 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221007000000_453.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221007000000_318.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221007000000_075.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221007040000_454.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221007040000_319.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221007040000_076.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221007080000_320.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221007080000_455.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221007080000_077.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221007120000_456.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221007120000_321.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221007120000_078.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221007160000_457.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221007160000_322.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221007160000_079.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221007200000_458.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221007200000_323.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221007200000_080.csv
# - loading
# saving to raw_2022-10-07_baro.pkl
# saving to raw_2022-10-07_100hz.pkl
# saving to raw_2022-10-07_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9729.838590958385, after: 0.13666037959072522
# min, max before: 9718.065, 9755.979
# min, max after: -0.03215438199999587, 0.2126942299999967
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9776.49943139916, after: 0.15106165496623125
# min, max before: 9773.158, 9783.859
# min, max after: 0.10375434799999757, 0.17254037600000355
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9154.152216388922, after: 4.255268497000967
# min, max before: 9147.863, 9163.521
# min, max after: 4.192272795999996, 4.297557188000004
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9472.43790154487, after: 3.6556674761494197
# min, max before: 9466.126, 9484.406
# min, max after: 3.578580953999994, 3.6963224339999985
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8616.754906998436, after: 9.021754125987622
# min, max before: 8607.687, 8624.323
# min, max after: 8.960641774999997, 9.094977475000002
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8348.508171893738, after: 8.675234464441127
# min, max before: 8343.274, 8354.532
# min, max after: 8.626188456000007, 8.717851092000005
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9064.25126393631, after: 3.4321322277962127
# min, max before: 9042.16796875, 9070.740234375
# min, max after: 3.390946732421875, 3.5722949023437502
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8421.340695728872, after: 8.340705487731373
# min, max before: 8415.6962890625, 8426.4130859375
# min, max after: 8.299933615234375, 8.386075228515624
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-10-08 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221008000000_324.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221008000000_459.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221008000000_081.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221008040000_325.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221008040000_460.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221008040000_082.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221008080000_461.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221008080000_326.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221008080000_083.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221008120000_462.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221008120000_327.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221008120000_084.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221008160000_463.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221008160000_328.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221008160000_085.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221008200000_464.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221008200000_329.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221008200000_086.csv
# - loading
# saving to raw_2022-10-08_100hz.pkl
# saving to raw_2022-10-08_baro.pkl
# saving to raw_2022-10-08_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9715.454135935859, after: 0.22955519012617884
# min, max before: 9700.101, 9755.535
# min, max after: -0.029287029999999062, 0.32870574199999636
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9778.296333303133, after: 0.13951116952752346
# min, max before: 9773.921, 9781.723
# min, max after: 0.11748455600000028, 0.16763581199999822
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9160.058407546252, after: 4.2155552676590835
# min, max before: 9154.056, 9168.274
# min, max after: 4.160313624000004, 4.255915455999997
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9478.647340506084, after: 3.6156724798003426
# min, max before: 9470.312, 9494.526
# min, max after: 3.513398034000001, 3.6693604080000006
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8621.671267635724, after: 8.98205451384149
# min, max before: 8613.913, 8632.214
# min, max after: 8.896921950000001, 9.044702524999996
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8353.344040920847, after: 8.635860818822442
# min, max before: 8347.628, 8360.99
# min, max after: 8.573607420000002, 8.682400823999995
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9070.56814577341, after: 3.392038978776142
# min, max before: 9064.82421875, 9078.2734375
# min, max after: 3.3431334921875, 3.42849568359375
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8426.2777676903, after: 8.30102130330534
# min, max before: 8420.9794921875, 8432.564453125
# min, max after: 8.25048892578125, 8.343608841796875
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-10-09 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221009000000_465.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221009000000_330.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221009000000_087.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221009040000_331.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221009040000_466.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221009040000_088.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221009080000_332.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221009080000_467.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221009080000_089.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221009120000_468.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221009120000_333.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221009120000_090.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221009160000_469.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221009160000_334.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221009160000_091.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221009200000_335.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221009200000_470.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221009200000_092.csv
# - loading
# saving to raw_2022-10-09_baro.pkl
# saving to raw_2022-10-09_100hz.pkl
# saving to raw_2022-10-09_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9705.264814661135, after: 0.29535782691843254
# min, max before: 9699.896, 9710.839
# min, max after: 0.2593597380000004, 0.33002963199999585
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9782.105695486765, after: 0.11502458941106611
# min, max before: 9777.407, 9786.191
# min, max after: 0.08876425199999541, 0.14522780400000485
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9150.985305753691, after: 4.276562804112152
# min, max before: 9143.92, 9155.879
# min, max after: 4.243657603999995, 4.3240699199999995
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9469.255959435506, after: 3.676162365275907
# min, max before: 9461.771, 9477.703
# min, max after: 3.621754977000003, 3.7243729889999955
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8613.170606126774, after: 9.050697355526331
# min, max before: 8604.072, 8623.677
# min, max after: 8.965858225000003, 9.124168599999999
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8344.853801616086, after: 8.704988347241855
# min, max before: 8339.537, 8349.394
# min, max after: 8.668022051999998, 8.748277745999998
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9060.912337959071, after: 3.4533243909738567
# min, max before: 9055.79296875, 9065.4658203125
# min, max after: 3.4244234384765626, 3.4858170273437503
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8417.709308287676, after: 8.369894579983622
# min, max before: 8412.904296875, 8421.708984375
# min, max after: 8.33774518359375, 8.40851726171875
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-10-10 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221010000000_471.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221010000000_336.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221010000000_093.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221010040000_337.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221010040000_472.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221010040000_094.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221010080000_338.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221010080000_473.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221010080000_095.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221010120000_474.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221010120000_339.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221010120000_096.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221010160000_340.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221010160000_475.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221010160000_097.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221010200000_341.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221010200000_476.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221010200000_098.csv
# - loading
# saving to raw_2022-10-10_baro.pkl
# saving to raw_2022-10-10_100hz.pkl
# saving to raw_2022-10-10_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9699.810648909543, after: 0.33058082934223415
# min, max before: 9693.118, 9710.36
# min, max after: 0.26245311999999626, 0.3738019559999975
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9777.930879518732, after: 0.14186030645356426
# min, max before: 9770.338, 9786.86
# min, max after: 0.08446391999999625, 0.19066733600000169
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9154.309395539347, after: 4.254211624393358
# min, max before: 9139.262, 9168.683
# min, max after: 4.157563507999994, 4.3553903119999955
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9472.801342814728, after: 3.6533265509303354
# min, max before: 9457.135, 9487.651
# min, max after: 3.557679909000001, 3.754233464999998
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8616.104663942468, after: 9.027004838664611
# min, max before: 8602.538, 8629.131
# min, max after: 8.921817175000005, 9.136555649999996
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8347.728381057366, after: 8.681583521430936
# min, max before: 8334.392, 8360.347
# min, max after: 8.578842726000001, 8.790168336
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9064.508925598842, after: 3.430496849224162
# min, max before: 9023.07421875, 9079.412109375
# min, max after: 3.3359063417968753, 3.6934829335937502
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8420.638989245872, after: 8.346345804441745
# min, max before: 8407.29296875, 8433.185546875
# min, max after: 8.24549657421875, 8.4536211171875
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-10-11 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221011000000_477.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221011000000_342.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221011000000_099.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221011040000_478.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221011040000_343.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221011040000_100.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221011080000_479.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221011080000_344.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221011080000_101.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221011120000_480.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221011120000_345.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221011120000_102.csv
# - loading
# saving to raw_2022-10-11_baro.pkl
# saving to raw_2022-10-11_100hz.pkl
# saving to raw_2022-10-11_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9696.041831326827, after: 0.3549198532913592
# min, max before: 9692.056, 9699.742
# min, max after: 0.3310241639999988, 0.3806603519999968
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9772.354722279619, after: 0.1777038451866542
# min, max before: 9767.487, 9776.883
# min, max after: 0.14859607600000121, 0.20899356400000532
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9166.169376363932, after: 4.174465113328891
# min, max before: 9160.303, 9170.371
# min, max after: 4.146213396000006, 4.213910628000001
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9485.224046145386, after: 3.573311918777638
# min, max before: 9475.026, 9489.507
# min, max after: 3.545725413000002, 3.638997534000001
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8626.997083067126, after: 8.939048554232953
# min, max before: 8620.058, 8630.887999999999
# min, max after: 8.907629400000008, 8.995081649999994
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8358.517184726517, after: 8.593741081956717
# min, max before: 8352.731, 8362.271
# min, max after: 8.563177517999994, 8.640852198000001
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9077.205906224106, after: 3.3499091131956096
# min, max before: 9038.6875, 9097.0888671875
# min, max after: 3.2237119599609376, 3.5943854375
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8431.58021721519, after: 8.258400214024363
# min, max before: 8426.1357421875, 8434.9794921875
# min, max after: 8.231076841796876, 8.302162904296875
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-10-12 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/Baro/100hz_Baro_Sensors_20221012083741_481.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221012083744_103.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/100hz/100hz_Sensors_100Hz_20221012083744_346.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221104/20hz/20hz_Sensors_20Hz_20221012090741_104.csv
# - loading
# ...
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221129120000_110.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221129160000_111.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221129160000_111.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221129160000_111.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221129200000_112.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221129200000_112.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221129200000_112.csv
# - loading
# saving to raw_2022-11-29_baro.pkl
# saving to raw_2022-11-29_100hz.pkl
# saving to raw_2022-11-29_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9715.01291699745, after: 0.23240458203042144
# min, max before: 9711.892, 9730.552
# min, max after: 0.13205318400000207, 0.2525594640000011
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9778.365691517662, after: 0.13906533492445755
# min, max before: 9769.785, 9799.208
# min, max after: 0.005090975999996539, 0.19422202000000094
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9136.846743465641, after: 4.371630496937025
# min, max before: 9130.258, 9185.04
# min, max after: 4.047579039999994, 4.415933208000001
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9456.64484732646, after: 3.7573905383702497
# min, max before: 1003.643, 9461.052
# min, max after: 3.729004068000002, 58.203175437
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8605.211401759325, after: 9.114967930793508
# min, max before: 602.7133000000013, 8664.173
# min, max after: 8.638853024999996, 73.7351401025
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8335.18670566453, after: 8.783697842479356
# min, max before: 8328.669, 8338.825
# min, max after: 8.754074849999993, 8.836765002000002
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9047.362030862889, after: 3.539328190113207
# min, max before: 1039.318359375, 9051.2431640625
# min, max after: 3.5146946376953125, 54.36638137304688
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8408.138531415681, after: 8.446824484480734
# min, max before: 8401.833984375, 8411.45703125
# min, max after: 8.4201503828125, 8.49750043359375
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-11-30 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221130000000_113.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221130000000_113.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221130000000_113.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221130092600_114.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221130092603_114.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221130092603_114.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221130120000_115.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221130120000_115.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221130120000_115.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221130160000_116.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221130160000_116.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221130160000_116.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221130200000_117.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221130200000_117.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221130200000_117.csv
# - loading
# saving to raw_2022-11-30_100hz.pkl
# saving to raw_2022-11-30_baro.pkl
# saving to raw_2022-11-30_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9714.730272980103, after: 0.2342298970945043
# min, max before: 9711.983, 9728.438
# min, max after: 0.14570539599999935, 0.25197178599999887
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9781.431509911547, after: 0.11935825428855869
# min, max before: 9736.751, 9787.569
# min, max after: 0.07990646800000317, 0.4065645719999987
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9140.023463508945, after: 4.3502702313657435
# min, max before: 9133.7, 9193.073
# min, max after: 3.993565147999998, 4.392789199999995
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9459.978711913962, after: 3.735917116562182
# min, max before: 9433.884, 30855.56
# min, max after: -134.07302196, 3.903993156
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8607.4450801502, after: 9.096930977787133
# min, max before: 6017.4490000000005, 8676.494
# min, max after: 8.539360949999995, 30.011149324999998
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8337.391706042008, after: 8.765744729405974
# min, max before: 8323.427, 8344.4
# min, max after: 8.708683200000003, 8.879445366000002
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9187.226740352835, after: 2.6516068789805325
# min, max before: 9045.7666015625, 9947.64453125
# min, max after: -2.1747648398437502, 3.5494543798828126
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8409.028207592333, after: 8.439673267372836
# min, max before: 8402.8515625, 8416.9755859375
# min, max after: 8.375792240234375, 8.489321140625
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-12-01 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221201093400_118.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221201093403_118.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221201093404_118.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221201120000_119.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221201120000_119.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221201120000_119.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221201160000_120.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221201160000_120.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221201160000_120.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221201200000_121.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221201200000_121.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221201200000_121.csv
# - loading
# saving to raw_2022-12-01_baro.pkl
# saving to raw_2022-12-01_20hz.pkl
# saving to raw_2022-12-01_100hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9706.801984222075, after: 0.2854307858937899
# min, max before: 9703.833, 9740.198
# min, max after: 0.06975931599999793, 0.3046044859999965
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9768.407781841926, after: 0.20307477832013243
# min, max before: 9701.935, 9775.202
# min, max after: 0.1594015440000044, 0.6303618200000033
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9144.98388908278, after: 4.316916329807324
# min, max before: 9079.674, 9150.703
# min, max after: 4.278461028000003, 4.756060023999994
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9465.196723687272, after: 3.702307902730235
# min, max before: 822.5143000000007, 9481.606
# min, max after: 3.5966157540000014, 59.36982539369999
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8612.431155443524, after: 9.056668419793619
# min, max before: 8514.7, 21138.4
# min, max after: -92.09053000000002, 9.845847499999994
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8342.323831600446, after: 8.725587363109108
# min, max before: 8337.531, 8370.258
# min, max after: 8.498147364000001, 8.764610597999994
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying calibration correction for 1226423
# mean before: 9056.850863168167, after: 3.4791025714716537
# min, max before: 7826.50537109375, 9061.38671875
# min, max after: 3.45031349609375, 11.288105409667969
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8415.608091744214, after: 8.386784158560003
# min, max before: 8411.80078125, 8419.20703125
# min, max after: 8.3578558828125, 8.4173873203125
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-12-02 00:00:00
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221202000000_122.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221202000000_122.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221202000000_122.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/Baro/100hz_Baro_Sensors_20221202082411_123.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/100hz/100hz_Sensors_100Hz_20221202082414_123.csv
# - loading
# /data/KSC/EROSION/fromdropboxinventory/03_merge_inventories/20221202/20hz/20hz_Sensors_20Hz_20221202082414_123.csv
# - loading
# saving to raw_2022-12-02_100hz.pkl
# saving to raw_2022-12-02_baro.pkl
# saving to raw_2022-12-02_20hz.pkl
# Applying height correction for AirPressureShallow
# Applying calibration correction for 1226420
# mean before: 9705.089781901444, after: 0.29648818848046826
# min, max before: 9697.354, 9713.697
# min, max after: 0.24090277399999926, 0.34644586800000415
# Applying temperature correction for 1226420
# Applying air pressure correction for 1226420
# Applying height correction for 1226420
# Applying calibration correction for 1226429
# mean before: 9767.576933056827, after: 0.20841547431071392
# min, max before: 9697.727, 9769.779
# min, max after: 0.1942605879999971, 0.657410843999995
# Applying temperature correction for 1226429
# Applying air pressure correction for 1226429
# Applying height correction for 1226429
# Applying calibration correction for 1226421
# mean before: 9142.928960848456, after: 4.330733667254984
# min, max before: 9121.186, 9321.41
# min, max after: 3.130627160000001, 4.476933336000002
# Applying temperature correction for 1226421
# Applying air pressure correction for 1226421
# Applying depth correction for 1226421
# Applying calibration correction for 1226419
# mean before: 9463.055559603676, after: 3.716099140592732
# min, max before: 2331.669, 9464.514
# min, max after: 3.7067053260000047, 49.649359970999996
# Applying temperature correction for 1226419
# Applying air pressure correction for 1226419
# Applying depth correction for 1226419
# Applying calibration correction for 2149882
# mean before: 8610.412878735984, after: 9.072966004206966
# min, max before: 514.9386, 8636.883
# min, max after: 8.859219775000001, 74.443920805
# Applying temperature correction for 2149882
# Applying air pressure correction for 2149882
# Applying depth correction for 2149882
# Applying calibration correction for 2151691
# mean before: 8340.340012782739, after: 8.741739615922942
# min, max before: 8332.885, 8341.567
# min, max after: 8.731749486000007, 8.802438329999998
# Applying temperature correction for 2151691
# Applying air pressure correction for 2151691
# Applying depth correction for 2151691
# Applying temperature correction for 1226423
# Applying air pressure correction for 1226423
# Applying depth correction for 1226423
# Applying calibration correction for 2151692
# mean before: 8411.842387562372, after: 8.41705288877366
# min, max before: 8406.77734375, 8414.322265625
# min, max after: 8.39711962890625, 8.4577657109375
# Applying temperature correction for 2151692
# Applying air pressure correction for 2151692
# Applying depth correction for 2151692
# - all corrected
# 2022-12-03 00:00:00
# No 100hz, no baro
